# %% [markdown]
# # Cattle Price Analysis: a comparison between Ireland and Spain

# %% [markdown]
# ### 0. Introduction

# %% [markdown]
# Agriculture

# %% [markdown]
# - **Import essential libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests 
import json

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 1. Data collection

# %% [markdown]
# Four datasets were collected online, i.e.:
# - beef price of Ireland and Spain from 2017 to 2021
# - beef production of Ireland and Spain from 2017 to 2021
# - beef feeding price of two stuff in Ireland from 2017 to 2021 (unfortunately the beef feeding price of Spain couldn't collect properly online
# - pigmeat price of Ireland and Spain from 2017 to 2021 (only the price of pigclass E was collected)

# %% [markdown]
# #### 1.1 Beef price

# %% [markdown]
# In this section, the beef price dataset was processed for merging later.

# %%
beef_price = pd.read_excel("beef_price_2017_2021.xlsx")
beef_price.head()
# Out:
#    Year  Week Begin Date   End Date Member State Category Product   Price
# 0  2021    52 2021-12-27 2022-01-02      Ireland    Bulls    B R3  333.26
# 1  2021    52 2021-12-27 2022-01-02        Spain     Cows    D R3  304.93
# 2  2021    52 2021-12-27 2022-01-02      Ireland     Cows    D R3  377.86
# 3  2021    52 2021-12-27 2022-01-02        Spain  Heifers    E R3  424.45
# 4  2021    52 2021-12-27 2022-01-02      Ireland  Heifers    E R3  434.96

# %%
beef_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2088 entries, 0 to 2087
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          2088 non-null   int64
#  1   Week          2088 non-null   int64
#  2   Begin Date    2088 non-null   datetime64[ns]
#  3   End Date      2088 non-null   datetime64[ns]
#  4   Member State  2088 non-null   object
#  5   Category      2088 non-null   object
#  6   Product       2088 non-null   object
#  7   Price         2088 non-null   float64
# dtypes: datetime64[ns](2), float64(1), int64(2), object(3)
# memory usage: 130.6+ KB

# %%
beef_price.shape
# Out:
# (2088, 8)

# %%
beef_price.isnull().sum()
# Out:
# Year            0
# Week            0
# Begin Date      0
# End Date        0
# Member State    0
# Category        0
# Product         0
# Price           0
# dtype: int64

# %%
# create a new column that shows date infomation (year-month)
beef_price["Month"] = beef_price["Begin Date"].dt.to_period("M")
beef_price.head()
# Out:
#    Year  Week Begin Date   End Date Member State Category Product   Price  \
# 0  2021    52 2021-12-27 2022-01-02      Ireland    Bulls    B R3  333.26
# 1  2021    52 2021-12-27 2022-01-02        Spain     Cows    D R3  304.93
# 2  2021    52 2021-12-27 2022-01-02      Ireland     Cows    D R3  377.86
# 3  2021    52 2021-12-27 2022-01-02        Spain  Heifers    E R3  424.45
# 4  2021    52 2021-12-27 2022-01-02      Ireland  Heifers    E R3  434.96
#
#      Month
# 0  2021-12
# 1  2021-12
# 2  2021-12
# 3  2021-12
# 4  2021-12

# %%
# create a group to generate the average monthly price of each product and each category in each country
# instead of showing the price weekly in the original dataset
# convenient for later merging also
beef_price_group = beef_price.groupby(["Member State", "Category", "Month"]).transform("mean")
beef_price_group
# Out:
#         Year  Week          Begin Date            End Date     Price
# 0     2021.0  50.5 2021-12-16 12:00:00 2021-12-22 12:00:00  321.9675
# 1     2021.0  50.5 2021-12-16 12:00:00 2021-12-22 12:00:00  304.8400
# 2     2021.0  50.5 2021-12-16 12:00:00 2021-12-22 12:00:00  378.2125
# 3     2021.0  50.5 2021-12-16 12:00:00 2021-12-22 12:00:00  426.5175
# 4     2021.0  50.5 2021-12-16 12:00:00 2021-12-22 12:00:00  431.5850
# ...      ...   ...                 ...                 ...       ...
# 2083  2017.0   3.0 2017-01-16 00:00:00 2017-01-22 00:00:00  388.4424
# 2084  2017.0   3.0 2017-01-16 00:00:00 2017-01-22 00:00:00  383.6880
# 2085  2017.0   3.0 2017-01-16 00:00:00 2017-01-22 00:00:00  370.5560
# 2086  2017.0   3.0 2017-01-16 00:00:00 2017-01-22 00:00:00  361.8120
# 2087  2017.0   3.0 2017-01-16 00:00:00 2017-01-22 00:00:00  372.4098
#
# [2088 rows x 5 columns]

# %%
# add a new column of the mean price to the dataset
beef_price["price"] = beef_price_group["Price"]
beef_price
# Out:
#       Year  Week Begin Date   End Date Member State     Category Product  \
# 0     2021    52 2021-12-27 2022-01-02      Ireland        Bulls    B R3
# 1     2021    52 2021-12-27 2022-01-02        Spain         Cows    D R3
# 2     2021    52 2021-12-27 2022-01-02      Ireland         Cows    D R3
# 3     2021    52 2021-12-27 2022-01-02        Spain      Heifers    E R3
# 4     2021    52 2021-12-27 2022-01-02      Ireland      Heifers    E R3
# ...    ...   ...        ...        ...          ...          ...     ...
# 2083  2017     1 2017-01-02 2017-01-08        Spain      Heifers    E R3
# 2084  2017     1 2017-01-02 2017-01-08      Ireland      Heifers    E R3
# 2085  2017     1 2017-01-02 2017-01-08      Ireland       Steers    C R3
# 2086  2017     1 2017-01-02 2017-01-08      Ireland  Young bulls    A R3
# 2087  2017     1 2017-01-02 2017-01-08        Spain  Young bulls    A R3
#
#         Price    Month     price
# 0     333.260  2021-12  321.9675
# 1     304.930  2021-12  304.8400
# 2     377.860  2021-12  378.2125
# 3     424.450  2021-12  426.5175
# 4     434.960  2021-12  431.5850
# ...       ...      ...       ...
# 2083  370.450  2017-01  388.4424
# 2084  382.150  2017-01  383.6880
# 2085  368.660  2017-01  370.5560
# 2086  361.230  2017-01  361.8120
# 2087  370.806  2017-01  372.4098
#
# [2088 rows x 10 columns]

# %%
# remove the prices that duplicating
beef_price = beef_price.drop_duplicates(["Member State", "Product", "price"], keep = "last")
beef_price.head(20)
# Out:
#     Year  Week Begin Date   End Date Member State     Category Product  \
# 24  2021    49 2021-12-06 2021-12-12      Ireland        Bulls    B R3
# 25  2021    49 2021-12-06 2021-12-12        Spain         Cows    D R3
# 26  2021    49 2021-12-06 2021-12-12      Ireland         Cows    D R3
# 27  2021    49 2021-12-06 2021-12-12        Spain      Heifers    E R3
# 28  2021    49 2021-12-06 2021-12-12      Ireland      Heifers    E R3
# 29  2021    49 2021-12-06 2021-12-12      Ireland       Steers    C R3
# 30  2021    49 2021-12-06 2021-12-12      Ireland  Young bulls    A R3
# 31  2021    49 2021-12-06 2021-12-12        Spain  Young bulls    A R3
# 64  2021    44 2021-11-01 2021-11-07      Ireland        Bulls    B R3
# 65  2021    44 2021-11-01 2021-11-07        Spain         Cows    D R3
# 66  2021    44 2021-11-01 2021-11-07      Ireland         Cows    D R3
# 67  2021    44 2021-11-01 2021-11-07      Ireland      Heifers    E R3
# 68  2021    44 2021-11-01 2021-11-07        Spain      Heifers    E R3
# 69  2021    44 2021-11-01 2021-11-07      Ireland       Steers    C R3
# 70  2021    44 2021-11-01 2021-11-07      Ireland  Young bulls    A R3
# 71  2021    44 2021-11-01 2021-11-07        Spain  Young bulls    A R3
# 96  2021    40 2021-10-04 2021-10-10      Ireland        Bulls    B R3
# 97  2021    40 2021-10-04 2021-10-10        Spain         Cows    D R3
# 98  2021    40 2021-10-04 2021-10-10      Ireland         Cows    D R3
# 99  2021    40 2021-10-04 2021-10-10        Spain      Heifers    E R3
#
#      Price    Month     price
# 24  312.81  2021-12  321.9675
# 25  302.30  2021-12  304.8400
# 26  380.18  2021-12  378.2125
# 27  421.74  2021-12  426.5175
# 28  428.07  2021-12  431.5850
# 29  424.52  2021-12  427.8350
# 30  406.65  2021-12  407.8750
# 31  439.50  2021-12  436.4375
# 64  306.72  2021-11  312.5720
# 65  293.63  2021-11  294.8920
# 66  366.77  2021-11  366.9300
# 67  419.99  2021-11  422.9340
# 68  422.15  2021-11  420.5860
# 69  414.74  2021-11  417.3040
# 70  399.66  2021-11  401.7100
# 71  407.40  2021-11  416.6060
# 96  293.20  2021-10  294.2975
# 97  291.80  2021-10  291.7875
# 98  373.66  2021-10  373.3200
# 99  406.72  2021-10  402.1075

# %%
beef_price = beef_price.drop(columns = {"Year", "Week", "Begin Date", "End Date", "Price"})
beef_price.head()
# Out:
#    Member State Category Product    Month     price
# 24      Ireland    Bulls    B R3  2021-12  321.9675
# 25        Spain     Cows    D R3  2021-12  304.8400
# 26      Ireland     Cows    D R3  2021-12  378.2125
# 27        Spain  Heifers    E R3  2021-12  426.5175
# 28      Ireland  Heifers    E R3  2021-12  431.5850

# %%
beef_price.columns = ["country", "category", "product", "date", "beef price/100kg"]
new_order = [-2, 0, 1, 2, -1]
beef_price = beef_price[beef_price.columns[new_order]]
beef_price.head()
# Out:
#        date  country category product  beef price/100kg
# 24  2021-12  Ireland    Bulls    B R3          321.9675
# 25  2021-12    Spain     Cows    D R3          304.8400
# 26  2021-12  Ireland     Cows    D R3          378.2125
# 27  2021-12    Spain  Heifers    E R3          426.5175
# 28  2021-12  Ireland  Heifers    E R3          431.5850

# %%
beef_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 480 entries, 24 to 2087
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              480 non-null    period[M]
#  1   country           480 non-null    object
#  2   category          480 non-null    object
#  3   product           480 non-null    object
#  4   beef price/100kg  480 non-null    float64
# dtypes: float64(1), object(3), period[M](1)
# memory usage: 22.5+ KB

# %%
beef_price["date"] = beef_price["date"].astype(str)
beef_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 480 entries, 24 to 2087
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              480 non-null    object
#  1   country           480 non-null    object
#  2   category          480 non-null    object
#  3   product           480 non-null    object
#  4   beef price/100kg  480 non-null    float64
# dtypes: float64(1), object(4)
# memory usage: 22.5+ KB

# %%
beef_price.shape
# Out:
# (480, 5)

# %%
beef_price["category"].unique()
# Out:
# array(['Bulls', 'Cows', 'Heifers', 'Steers', 'Young bulls'], dtype=object)

# %%
beef_price["country"].unique()
# Out:
# array(['Ireland', 'Spain'], dtype=object)

# %%
beef_price["product"].unique()
# Out:
# array(['B R3', 'D R3', 'E R3', 'C R3', 'A R3'], dtype=object)

# %% [markdown]
# #### 1.2 Beef production

# %% [markdown]
# In this section, the beef production dataset was processed for merging later.

# %%
beef_production = pd.read_excel("beef_production_2017_2021.xlsx")
beef_production.head()
# Out:
#   Member State Member State Code Category  Year     Month  1000 Heads  \
# 0      Ireland                IE     Bull  2021   January       15.67
# 1      Ireland                IE     Bull  2021  February       14.85
# 2      Ireland                IE     Bull  2021     March       14.19
# 3      Ireland                IE     Bull  2021     April       11.95
# 4      Ireland                IE     Bull  2021       May       15.61
#
#       kg/head
# 0  376.515635
# 1  383.164983
# 2  394.644116
# 3  403.347280
# 4  393.978219

# %%
beef_production.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Member State       600 non-null    object
#  1   Member State Code  600 non-null    object
#  2   Category           600 non-null    object
#  3   Year               600 non-null    int64
#  4   Month              600 non-null    object
#  5   1000 Heads         600 non-null    float64
#  6   kg/head            600 non-null    float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 32.9+ KB

# %%
beef_production.shape
# Out:
# (600, 7)

# %%
beef_production.isnull().sum()
# Out:
# Member State         0
# Member State Code    0
# Category             0
# Year                 0
# Month                0
# 1000 Heads           0
# kg/head              0
# dtype: int64

# %%
# create a new date column based on Year and Month column
beef_production["date"] = pd.to_datetime(beef_production["Year"].astype(str)  + beef_production["Month"], format = "%Y%B")
beef_production.head()
# Out:
#   Member State Member State Code Category  Year     Month  1000 Heads  \
# 0      Ireland                IE     Bull  2021   January       15.67
# 1      Ireland                IE     Bull  2021  February       14.85
# 2      Ireland                IE     Bull  2021     March       14.19
# 3      Ireland                IE     Bull  2021     April       11.95
# 4      Ireland                IE     Bull  2021       May       15.61
#
#       kg/head       date
# 0  376.515635 2021-01-01
# 1  383.164983 2021-02-01
# 2  394.644116 2021-03-01
# 3  403.347280 2021-04-01
# 4  393.978219 2021-05-01

# %%
# change the date format into year-month
beef_production["date"] = beef_production["date"].dt.date.apply(lambda x: x.strftime('%Y-%m'))
beef_production
# Out:
#     Member State Member State Code      Category  Year      Month  1000 Heads  \
# 0        Ireland                IE          Bull  2021    January       15.67
# 1        Ireland                IE          Bull  2021   February       14.85
# 2        Ireland                IE          Bull  2021      March       14.19
# 3        Ireland                IE          Bull  2021      April       11.95
# 4        Ireland                IE          Bull  2021        May       15.61
# ..           ...               ...           ...   ...        ...         ...
# 595        Spain                ES  Young cattle  2017     August       85.21
# 596        Spain                ES  Young cattle  2017  September       83.32
# 597        Spain                ES  Young cattle  2017    October       87.65
# 598        Spain                ES  Young cattle  2017   November       84.57
# 599        Spain                ES  Young cattle  2017   December       87.73
#
#         kg/head     date
# 0    376.515635  2021-01
# 1    383.164983  2021-02
# 2    394.644116  2021-03
# 3    403.347280  2021-04
# 4    393.978219  2021-05
# ..          ...      ...
# 595  241.286234  2017-08
# 596  241.358617  2017-09
# 597  240.844267  2017-10
# 598  240.392574  2017-11
# 599  239.028838  2017-12
#
# [600 rows x 8 columns]

# %%
beef_production = beef_production.drop(columns = {"Member State Code", "Year", "Month"})
beef_production.head()
# Out:
#   Member State Category  1000 Heads     kg/head     date
# 0      Ireland     Bull       15.67  376.515635  2021-01
# 1      Ireland     Bull       14.85  383.164983  2021-02
# 2      Ireland     Bull       14.19  394.644116  2021-03
# 3      Ireland     Bull       11.95  403.347280  2021-04
# 4      Ireland     Bull       15.61  393.978219  2021-05

# %%
print(beef_production["Member State"].unique())
print(beef_price["country"].unique())
# Out:
# ['Ireland' 'Spain']
# ['Ireland' 'Spain']

# %%
print(beef_production["Category"].unique())
print(beef_price["category"].unique())
# Out:
# ['Bull' 'Bullock' 'Cow' 'Heifer' 'Young cattle']
# ['Bulls' 'Cows' 'Heifers' 'Steers' 'Young bulls']

# %%
# align the unique values of category in beef production with beef price
beef_production["Category"].replace(["Bull", "Bullock", "Cow", "Heifer", "Young cattle"], 
                                    ["Bulls", "Steers", "Cows", "Heifers", "Young bulls"], inplace=True)
beef_production.head()
# Out:
#   Member State Category  1000 Heads     kg/head     date
# 0      Ireland    Bulls       15.67  376.515635  2021-01
# 1      Ireland    Bulls       14.85  383.164983  2021-02
# 2      Ireland    Bulls       14.19  394.644116  2021-03
# 3      Ireland    Bulls       11.95  403.347280  2021-04
# 4      Ireland    Bulls       15.61  393.978219  2021-05

# %%
beef_production.columns = ["country", "category", "1000 heads", "kg/head", "date"]
new_order2 = [-1, 0, 1, 2, -2]
beef_production = beef_production[beef_production.columns[new_order2]]
beef_production.head()
# Out:
#       date  country category  1000 heads     kg/head
# 0  2021-01  Ireland    Bulls       15.67  376.515635
# 1  2021-02  Ireland    Bulls       14.85  383.164983
# 2  2021-03  Ireland    Bulls       14.19  394.644116
# 3  2021-04  Ireland    Bulls       11.95  403.347280
# 4  2021-05  Ireland    Bulls       15.61  393.978219

# %%
beef_production.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        600 non-null    object
#  1   country     600 non-null    object
#  2   category    600 non-null    object
#  3   1000 heads  600 non-null    float64
#  4   kg/head     600 non-null    float64
# dtypes: float64(2), object(3)
# memory usage: 23.6+ KB

# %%
beef_production.shape
# Out:
# (600, 5)

# %%
beef_production["country"].unique()
# Out:
# array(['Ireland', 'Spain'], dtype=object)

# %%
beef_production["category"].unique()
# Out:
# array(['Bulls', 'Steers', 'Cows', 'Heifers', 'Young bulls'], dtype=object)

# %% [markdown]
# #### 1.3 Beef feeding price

# %% [markdown]
# In this section, the beef feeding price of Ireland was processed for merging later.

# %%
beef_feeding_price = pd.read_csv("beef_feeding_price_Ireland_2017_2021.csv")
beef_feeding_price.head()
# Out:
#     STATISTIC Label          Month  \
# 0  Feed Stuff Price   2017 January
# 1  Feed Stuff Price   2017 January
# 2  Feed Stuff Price  2017 February
# 3  Feed Stuff Price  2017 February
# 4  Feed Stuff Price     2017 March
#
#                                   Type of Feedstuff            UNIT   VALUE
# 0  Cattle fattening nuts and cubes (13-15% protein)  Euro per Tonne  262.44
# 1            Cattle fattening meal (13-15% protein)  Euro per Tonne  250.44
# 2  Cattle fattening nuts and cubes (13-15% protein)  Euro per Tonne  264.56
# 3            Cattle fattening meal (13-15% protein)  Euro per Tonne  248.93
# 4  Cattle fattening nuts and cubes (13-15% protein)  Euro per Tonne  265.00

# %%
beef_feeding_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   STATISTIC Label    140 non-null    object
#  1   Month              140 non-null    object
#  2   Type of Feedstuff  140 non-null    object
#  3   UNIT               140 non-null    object
#  4   VALUE              140 non-null    float64
# dtypes: float64(1), object(4)
# memory usage: 5.6+ KB

# %%
from datetime import datetime

# create a function to convert dates
def date_conversion(el):
    return datetime.strptime(el, "%Y %B").strftime("%Y-%m")


# apply conversion to desired column and store output in a new column
beef_feeding_price["date"] = beef_feeding_price["Month"].apply(date_conversion)
beef_feeding_price.head()
# Out:
#     STATISTIC Label          Month  \
# 0  Feed Stuff Price   2017 January
# 1  Feed Stuff Price   2017 January
# 2  Feed Stuff Price  2017 February
# 3  Feed Stuff Price  2017 February
# 4  Feed Stuff Price     2017 March
#
#                                   Type of Feedstuff            UNIT   VALUE  \
# 0  Cattle fattening nuts and cubes (13-15% protein)  Euro per Tonne  262.44
# 1            Cattle fattening meal (13-15% protein)  Euro per Tonne  250.44
# 2  Cattle fattening nuts and cubes (13-15% protein)  Euro per Tonne  264.56
# 3            Cattle fattening meal (13-15% protein)  Euro per Tonne  248.93
# 4  Cattle fattening nuts and cubes (13-15% protein)  Euro per Tonne  265.00
#
#       date
# 0  2017-01
# 1  2017-01
# 2  2017-02
# 3  2017-02
# 4  2017-03

# %%
beef_feeding_price = beef_feeding_price.drop(columns = {"STATISTIC Label", "Month", "UNIT"})
beef_feeding_price.head()
# Out:
#                                   Type of Feedstuff   VALUE     date
# 0  Cattle fattening nuts and cubes (13-15% protein)  262.44  2017-01
# 1            Cattle fattening meal (13-15% protein)  250.44  2017-01
# 2  Cattle fattening nuts and cubes (13-15% protein)  264.56  2017-02
# 3            Cattle fattening meal (13-15% protein)  248.93  2017-02
# 4  Cattle fattening nuts and cubes (13-15% protein)  265.00  2017-03

# %%
beef_feeding_price.columns = ["feedstuff", "beef feeding price/tonne", "date"]
new_order3 = [2, 0, 1]
beef_feeding_price = beef_feeding_price[beef_feeding_price.columns[new_order3]]
beef_feeding_price.head()
# Out:
#       date                                         feedstuff  \
# 0  2017-01  Cattle fattening nuts and cubes (13-15% protein)
# 1  2017-01            Cattle fattening meal (13-15% protein)
# 2  2017-02  Cattle fattening nuts and cubes (13-15% protein)
# 3  2017-02            Cattle fattening meal (13-15% protein)
# 4  2017-03  Cattle fattening nuts and cubes (13-15% protein)
#
#    beef feeding price/tonne
# 0                    262.44
# 1                    250.44
# 2                    264.56
# 3                    248.93
# 4                    265.00

# %% [markdown]
# - Filter into two datasets for merging later.

# %%
feedstuff1 = beef_feeding_price.query("feedstuff == 'Cattle fattening nuts and cubes (13-15% protein)'")
feedstuff1.head()
# Out:
#       date                                         feedstuff  \
# 0  2017-01  Cattle fattening nuts and cubes (13-15% protein)
# 2  2017-02  Cattle fattening nuts and cubes (13-15% protein)
# 4  2017-03  Cattle fattening nuts and cubes (13-15% protein)
# 6  2017-04  Cattle fattening nuts and cubes (13-15% protein)
# 8  2017-05  Cattle fattening nuts and cubes (13-15% protein)
#
#    beef feeding price/tonne
# 0                    262.44
# 2                    264.56
# 4                    265.00
# 6                    265.39
# 8                    265.67

# %%
feedstuff2 = beef_feeding_price.query("feedstuff == 'Cattle fattening meal (13-15% protein)'")
feedstuff2.head()
# Out:
#       date                               feedstuff  beef feeding price/tonne
# 1  2017-01  Cattle fattening meal (13-15% protein)                    250.44
# 3  2017-02  Cattle fattening meal (13-15% protein)                    248.93
# 5  2017-03  Cattle fattening meal (13-15% protein)                    249.00
# 7  2017-04  Cattle fattening meal (13-15% protein)                    249.44
# 9  2017-05  Cattle fattening meal (13-15% protein)                    249.75

# %% [markdown]
# #### 1.4 Pigmeat price

# %% [markdown]
# In this section, the pigmeat price was collected through API and then processed for merging later.

# %%
# Get a request from the europa api that filter out the pigmeat price of Spain and Ireland from 2017 to 2021
# Only extract the E pigclass using the unit of 100KG
api_pigprice = "https://ec.europa.eu/agrifood/api/pigmeat/prices"

pigprice = {"memberStateCodes" : "ES,IE",
            "pigClasses" : "E",
            "beginDate" : "02/01/2017",
            "endDate" : "02/01/2022",
            "unit" : "100 KG"
    } 

response_pigprice = requests.get(api_pigprice, params=pigprice)

print(response_pigprice.status_code)
print(response_pigprice.url)
# Out:
# 200
# https://ec.europa.eu/agrifood/api/pigmeat/prices?memberStateCodes=ES%2CIE&pigClasses=E&beginDate=02%2F01%2F2017&endDate=02%2F01%2F2022&unit=100+KG

# %%
# check the json file
response_pigprice.json()
# Out:
# [{'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '27/12/2021',
#   'endDate': '02/01/2022',
#   'weekNumber': 52,
#   'price': '€143,39',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '27/12/2021',
#   'endDate': '02/01/2022',
#   'weekNumber': 52,
#   'price': '€126,29',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '20/12/2021',
#   'endDate': '26/12/2021',
#   'weekNumber': 51,
#   'price': '€143,57',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '20/12/2021',
#   'endDate': '26/12/2021',
#   'weekNumber': 51,
#   'price': '€127,28',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '13/12/2021',
#   'endDate': '19/12/2021',
#   'weekNumber': 50,
#   'price': '€143,77',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '13/12/2021',
#   'endDate': '19/12/2021',
#   'weekNumber': 50,
#   'price': '€126,07',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '06/12/2021',
#   'endDate': '12/12/2021',
#   'weekNumber': 49,
#   'price': '€143,47',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '06/12/2021',
#   'endDate': '12/12/2021',
#   'weekNumber': 49,
#   'price': '€123,88',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '29/11/2021',
#   'endDate': '05/12/2021',
#   'weekNumber': 48,
#   'price': '€143,65',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '29/11/2021',
#   'endDate': '05/12/2021',
#   'weekNumber': 48,
#   'price': '€126,01',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '22/11/2021',
#   'endDate': '28/11/2021',
#   'weekNumber': 47,
#   'price': '€143,36',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '22/11/2021',
#   'endDate': '28/11/2021',
#   'weekNumber': 47,
#   'price': '€125,56',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '15/11/2021',
#   'endDate': '21/11/2021',
#   'weekNumber': 46,
#   'price': '€143,22',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '15/11/2021',
#   'endDate': '21/11/2021',
#   'weekNumber': 46,
#   'price': '€126,49',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '08/11/2021',
#   'endDate': '14/11/2021',
#   'weekNumber': 45,
#   'price': '€143,50',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '08/11/2021',
#   'endDate': '14/11/2021',
#   'weekNumber': 45,
#   'price': '€126,30',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '01/11/2021',
#   'endDate': '07/11/2021',
#   'weekNumber': 44,
#   'price': '€143,48',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '01/11/2021',
#   'endDate': '07/11/2021',
#   'weekNumber': 44,
#   'price': '€126,49',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '25/10/2021',
#   'endDate': '31/10/2021',
#   'weekNumber': 43,
#   'price': '€145,76',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '25/10/2021',
#   'endDate': '31/10/2021',
#   'weekNumber': 43,
#   'price': '€128,52',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '18/10/2021',
#   'endDate': '24/10/2021',
#   'weekNumber': 42,
#   'price': '€147,75',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '18/10/2021',
#   'endDate': '24/10/2021',
#   'weekNumber': 42,
#   'price': '€130,50',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '11/10/2021',
#   'endDate': '17/10/2021',
#   'weekNumber': 41,
#   'price': '€147,80',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '11/10/2021',
#   'endDate': '17/10/2021',
#   'weekNumber': 41,
#   'price': '€134,85',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '04/10/2021',
#   'endDate': '10/10/2021',
#   'weekNumber': 40,
#   'price': '€149,77',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '04/10/2021',
#   'endDate': '10/10/2021',
#   'weekNumber': 40,
#   'price': '€138,84',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '27/09/2021',
#   'endDate': '03/10/2021',
#   'weekNumber': 39,
#   'price': '€151,53',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '27/09/2021',
#   'endDate': '03/10/2021',
#   'weekNumber': 39,
#   'price': '€141,96',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '20/09/2021',
#   'endDate': '26/09/2021',
#   'weekNumber': 38,
#   'price': '€151,57',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '20/09/2021',
#   'endDate': '26/09/2021',
#   'weekNumber': 38,
#   'price': '€144,96',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '13/09/2021',
#   'endDate': '19/09/2021',
#   'weekNumber': 37,
#   'price': '€151,51',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '13/09/2021',
#   'endDate': '19/09/2021',
#   'weekNumber': 37,
#   'price': '€147,44',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '06/09/2021',
#   'endDate': '12/09/2021',
#   'weekNumber': 36,
#   'price': '€151,40',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '06/09/2021',
#   'endDate': '12/09/2021',
#   'weekNumber': 36,
#   'price': '€150,16',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '30/08/2021',
#   'endDate': '05/09/2021',
#   'weekNumber': 35,
#   'price': '€153,29',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '30/08/2021',
#   'endDate': '05/09/2021',
#   'weekNumber': 35,
#   'price': '€152,07',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '23/08/2021',
#   'endDate': '29/08/2021',
#   'weekNumber': 34,
#   'price': '€155,29',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '23/08/2021',
#   'endDate': '29/08/2021',
#   'weekNumber': 34,
#   'price': '€153,25',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '16/08/2021',
#   'endDate': '22/08/2021',
#   'weekNumber': 33,
#   'price': '€155,37',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '16/08/2021',
#   'endDate': '22/08/2021',
#   'weekNumber': 33,
#   'price': '€155,07',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '09/08/2021',
#   'endDate': '15/08/2021',
#   'weekNumber': 32,
#   'price': '€155,46',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '09/08/2021',
#   'endDate': '15/08/2021',
#   'weekNumber': 32,
#   'price': '€158,06',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '02/08/2021',
#   'endDate': '08/08/2021',
#   'weekNumber': 31,
#   'price': '€159,36',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '02/08/2021',
#   'endDate': '08/08/2021',
#   'weekNumber': 31,
#   'price': '€159,66',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '26/07/2021',
#   'endDate': '01/08/2021',
#   'weekNumber': 30,
#   'price': '€159,18',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '26/07/2021',
#   'endDate': '01/08/2021',
#   'weekNumber': 30,
#   'price': '€163,20',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '19/07/2021',
#   'endDate': '25/07/2021',
#   'weekNumber': 29,
#   'price': '€159,35',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '19/07/2021',
#   'endDate': '25/07/2021',
#   'weekNumber': 29,
#   'price': '€173,48',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '12/07/2021',
#   'endDate': '18/07/2021',
#   'weekNumber': 28,
#   'price': '€161,28',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '12/07/2021',
#   'endDate': '18/07/2021',
#   'weekNumber': 28,
#   'price': '€173,48',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '05/07/2021',
#   'endDate': '11/07/2021',
#   'weekNumber': 27,
#   'price': '€163,30',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '05/07/2021',
#   'endDate': '11/07/2021',
#   'weekNumber': 27,
#   'price': '€179,10',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '28/06/2021',
#   'endDate': '04/07/2021',
#   'weekNumber': 26,
#   'price': '€167,29',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '28/06/2021',
#   'endDate': '04/07/2021',
#   'weekNumber': 26,
#   'price': '€184,81',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '21/06/2021',
#   'endDate': '27/06/2021',
#   'weekNumber': 25,
#   'price': '€167,25',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '21/06/2021',
#   'endDate': '27/06/2021',
#   'weekNumber': 25,
#   'price': '€190,26',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '14/06/2021',
#   'endDate': '20/06/2021',
#   'weekNumber': 24,
#   'price': '€167,12',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '14/06/2021',
#   'endDate': '20/06/2021',
#   'weekNumber': 24,
#   'price': '€190,16',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '07/06/2021',
#   'endDate': '13/06/2021',
#   'weekNumber': 23,
#   'price': '€167,26',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '07/06/2021',
#   'endDate': '13/06/2021',
#   'weekNumber': 23,
#   'price': '€188,85',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '31/05/2021',
#   'endDate': '06/06/2021',
#   'weekNumber': 22,
#   'price': '€167,11',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '31/05/2021',
#   'endDate': '06/06/2021',
#   'weekNumber': 22,
#   'price': '€186,23',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '24/05/2021',
#   'endDate': '30/05/2021',
#   'weekNumber': 21,
#   'price': '€166,94',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '24/05/2021',
#   'endDate': '30/05/2021',
#   'weekNumber': 21,
#   'price': '€186,82',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '17/05/2021',
#   'endDate': '23/05/2021',
#   'weekNumber': 20,
#   'price': '€165,01',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '17/05/2021',
#   'endDate': '23/05/2021',
#   'weekNumber': 20,
#   'price': '€181,32',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '10/05/2021',
#   'endDate': '16/05/2021',
#   'weekNumber': 19,
#   'price': '€164,98',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '10/05/2021',
#   'endDate': '16/05/2021',
#   'weekNumber': 19,
#   'price': '€179,27',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '03/05/2021',
#   'endDate': '09/05/2021',
#   'weekNumber': 18,
#   'price': '€164,82',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '03/05/2021',
#   'endDate': '09/05/2021',
#   'weekNumber': 18,
#   'price': '€177,91',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '26/04/2021',
#   'endDate': '02/05/2021',
#   'weekNumber': 17,
#   'price': '€165,12',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '26/04/2021',
#   'endDate': '02/05/2021',
#   'weekNumber': 17,
#   'price': '€177,80',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '19/04/2021',
#   'endDate': '25/04/2021',
#   'weekNumber': 16,
#   'price': '€163,13',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '19/04/2021',
#   'endDate': '25/04/2021',
#   'weekNumber': 16,
#   'price': '€179,74',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '12/04/2021',
#   'endDate': '18/04/2021',
#   'weekNumber': 15,
#   'price': '€163,01',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '12/04/2021',
#   'endDate': '18/04/2021',
#   'weekNumber': 15,
#   'price': '€178,32',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '05/04/2021',
#   'endDate': '11/04/2021',
#   'weekNumber': 14,
#   'price': '€159,16',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '05/04/2021',
#   'endDate': '11/04/2021',
#   'weekNumber': 14,
#   'price': '€177,48',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '29/03/2021',
#   'endDate': '04/04/2021',
#   'weekNumber': 13,
#   'price': '€159,12',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '29/03/2021',
#   'endDate': '04/04/2021',
#   'weekNumber': 13,
#   'price': '€177,97',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '22/03/2021',
#   'endDate': '28/03/2021',
#   'weekNumber': 12,
#   'price': '€155,27',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '22/03/2021',
#   'endDate': '28/03/2021',
#   'weekNumber': 12,
#   'price': '€171,31',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '15/03/2021',
#   'endDate': '21/03/2021',
#   'weekNumber': 11,
#   'price': '€155,29',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '15/03/2021',
#   'endDate': '21/03/2021',
#   'weekNumber': 11,
#   'price': '€164,97',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '08/03/2021',
#   'endDate': '14/03/2021',
#   'weekNumber': 10,
#   'price': '€155,30',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '08/03/2021',
#   'endDate': '14/03/2021',
#   'weekNumber': 10,
#   'price': '€158,09',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '01/03/2021',
#   'endDate': '07/03/2021',
#   'weekNumber': 9,
#   'price': '€151,37',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '01/03/2021',
#   'endDate': '07/03/2021',
#   'weekNumber': 9,
#   'price': '€150,85',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '22/02/2021',
#   'endDate': '28/02/2021',
#   'weekNumber': 8,
#   'price': '€151,26',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '22/02/2021',
#   'endDate': '28/02/2021',
#   'weekNumber': 8,
#   'price': '€144,10',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '15/02/2021',
#   'endDate': '21/02/2021',
#   'weekNumber': 7,
#   'price': '€151,80',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '15/02/2021',
#   'endDate': '21/02/2021',
#   'weekNumber': 7,
#   'price': '€140,07',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '08/02/2021',
#   'endDate': '14/02/2021',
#   'weekNumber': 6,
#   'price': '€151,54',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '08/02/2021',
#   'endDate': '14/02/2021',
#   'weekNumber': 6,
#   'price': '€137,36',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '01/02/2021',
#   'endDate': '07/02/2021',
#   'weekNumber': 5,
#   'price': '€151,59',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '01/02/2021',
#   'endDate': '07/02/2021',
#   'weekNumber': 5,
#   'price': '€134,89',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '25/01/2021',
#   'endDate': '31/01/2021',
#   'weekNumber': 4,
#   'price': '€151,68',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '25/01/2021',
#   'endDate': '31/01/2021',
#   'weekNumber': 4,
#   'price': '€134,48',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '18/01/2021',
#   'endDate': '24/01/2021',
#   'weekNumber': 3,
#   'price': '€153,27',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '18/01/2021',
#   'endDate': '24/01/2021',
#   'weekNumber': 3,
#   'price': '€135,02',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '11/01/2021',
#   'endDate': '17/01/2021',
#   'weekNumber': 2,
#   'price': '€155,22',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '11/01/2021',
#   'endDate': '17/01/2021',
#   'weekNumber': 2,
#   'price': '€135,31',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '04/01/2021',
#   'endDate': '10/01/2021',
#   'weekNumber': 1,
#   'price': '€155,36',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '04/01/2021',
#   'endDate': '10/01/2021',
#   'weekNumber': 1,
#   'price': '€135,90',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '28/12/2020',
#   'endDate': '03/01/2021',
#   'weekNumber': 53,
#   'price': '€157,00',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '28/12/2020',
#   'endDate': '03/01/2021',
#   'weekNumber': 53,
#   'price': '€136,00',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '21/12/2020',
#   'endDate': '27/12/2020',
#   'weekNumber': 52,
#   'price': '€155,76',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '21/12/2020',
#   'endDate': '27/12/2020',
#   'weekNumber': 52,
#   'price': '€135,83',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '14/12/2020',
#   'endDate': '20/12/2020',
#   'weekNumber': 51,
#   'price': '€155,79',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '14/12/2020',
#   'endDate': '20/12/2020',
#   'weekNumber': 51,
#   'price': '€135,31',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '07/12/2020',
#   'endDate': '13/12/2020',
#   'weekNumber': 50,
#   'price': '€155,63',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '07/12/2020',
#   'endDate': '13/12/2020',
#   'weekNumber': 50,
#   'price': '€136,04',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '30/11/2020',
#   'endDate': '06/12/2020',
#   'weekNumber': 49,
#   'price': '€155,57',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '30/11/2020',
#   'endDate': '06/12/2020',
#   'weekNumber': 49,
#   'price': '€141,45',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '23/11/2020',
#   'endDate': '29/11/2020',
#   'weekNumber': 48,
#   'price': '€155,51',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '23/11/2020',
#   'endDate': '29/11/2020',
#   'weekNumber': 48,
#   'price': '€143,86',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '16/11/2020',
#   'endDate': '22/11/2020',
#   'weekNumber': 47,
#   'price': '€157,42',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '16/11/2020',
#   'endDate': '22/11/2020',
#   'weekNumber': 47,
#   'price': '€148,06',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '09/11/2020',
#   'endDate': '15/11/2020',
#   'weekNumber': 46,
#   'price': '€159,34',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '09/11/2020',
#   'endDate': '15/11/2020',
#   'weekNumber': 46,
#   'price': '€151,86',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '02/11/2020',
#   'endDate': '08/11/2020',
#   'weekNumber': 45,
#   'price': '€159,29',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '02/11/2020',
#   'endDate': '08/11/2020',
#   'weekNumber': 45,
#   'price': '€154,52',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '26/10/2020',
#   'endDate': '01/11/2020',
#   'weekNumber': 44,
#   'price': '€159,34',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '26/10/2020',
#   'endDate': '01/11/2020',
#   'weekNumber': 44,
#   'price': '€156,25',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '19/10/2020',
#   'endDate': '25/10/2020',
#   'weekNumber': 43,
#   'price': '€157,14',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '12/10/2020',
#   'endDate': '18/10/2020',
#   'weekNumber': 42,
#   'price': '€158,15',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '05/10/2020',
#   'endDate': '11/10/2020',
#   'weekNumber': 41,
#   'price': '€159,18',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '05/10/2020',
#   'endDate': '11/10/2020',
#   'weekNumber': 41,
#   'price': '€156,12',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '28/09/2020',
#   'endDate': '04/10/2020',
#   'weekNumber': 40,
#   'price': '€159,37',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '28/09/2020',
#   'endDate': '04/10/2020',
#   'weekNumber': 40,
#   'price': '€157,10',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '21/09/2020',
#   'endDate': '27/09/2020',
#   'weekNumber': 39,
#   'price': '€159,33',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '21/09/2020',
#   'endDate': '27/09/2020',
#   'weekNumber': 39,
#   'price': '€158,32',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '14/09/2020',
#   'endDate': '20/09/2020',
#   'weekNumber': 38,
#   'price': '€159,10',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '14/09/2020',
#   'endDate': '20/09/2020',
#   'weekNumber': 38,
#   'price': '€158,22',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '07/09/2020',
#   'endDate': '13/09/2020',
#   'weekNumber': 37,
#   'price': '€159,16',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '07/09/2020',
#   'endDate': '13/09/2020',
#   'weekNumber': 37,
#   'price': '€158,08',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '31/08/2020',
#   'endDate': '06/09/2020',
#   'weekNumber': 36,
#   'price': '€159,13',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '31/08/2020',
#   'endDate': '06/09/2020',
#   'weekNumber': 36,
#   'price': '€158,38',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '24/08/2020',
#   'endDate': '30/08/2020',
#   'weekNumber': 35,
#   'price': '€159,11',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '24/08/2020',
#   'endDate': '30/08/2020',
#   'weekNumber': 35,
#   'price': '€159,19',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '17/08/2020',
#   'endDate': '23/08/2020',
#   'weekNumber': 34,
#   'price': '€162,90',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '17/08/2020',
#   'endDate': '23/08/2020',
#   'weekNumber': 34,
#   'price': '€159,34',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '10/08/2020',
#   'endDate': '16/08/2020',
#   'weekNumber': 33,
#   'price': '€162,92',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '10/08/2020',
#   'endDate': '16/08/2020',
#   'weekNumber': 33,
#   'price': '€159,85',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '03/08/2020',
#   'endDate': '09/08/2020',
#   'weekNumber': 32,
#   'price': '€162,87',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '03/08/2020',
#   'endDate': '09/08/2020',
#   'weekNumber': 32,
#   'price': '€157,85',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '27/07/2020',
#   'endDate': '02/08/2020',
#   'weekNumber': 31,
#   'price': '€162,81',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '27/07/2020',
#   'endDate': '02/08/2020',
#   'weekNumber': 31,
#   'price': '€153,81',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '20/07/2020',
#   'endDate': '26/07/2020',
#   'weekNumber': 30,
#   'price': '€162,95',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '20/07/2020',
#   'endDate': '26/07/2020',
#   'weekNumber': 30,
#   'price': '€159,28',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '13/07/2020',
#   'endDate': '19/07/2020',
#   'weekNumber': 29,
#   'price': '€162,97',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '13/07/2020',
#   'endDate': '19/07/2020',
#   'weekNumber': 29,
#   'price': '€161,58',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '06/07/2020',
#   'endDate': '12/07/2020',
#   'weekNumber': 28,
#   'price': '€162,89',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '06/07/2020',
#   'endDate': '12/07/2020',
#   'weekNumber': 28,
#   'price': '€161,54',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '29/06/2020',
#   'endDate': '05/07/2020',
#   'weekNumber': 27,
#   'price': '€162,58',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '29/06/2020',
#   'endDate': '05/07/2020',
#   'weekNumber': 27,
#   'price': '€161,80',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '22/06/2020',
#   'endDate': '28/06/2020',
#   'weekNumber': 26,
#   'price': '€162,42',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '22/06/2020',
#   'endDate': '28/06/2020',
#   'weekNumber': 26,
#   'price': '€161,33',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '15/06/2020',
#   'endDate': '21/06/2020',
#   'weekNumber': 25,
#   'price': '€162,41',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '15/06/2020',
#   'endDate': '21/06/2020',
#   'weekNumber': 25,
#   'price': '€158,69',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '08/06/2020',
#   'endDate': '14/06/2020',
#   'weekNumber': 24,
#   'price': '€162,22',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '08/06/2020',
#   'endDate': '14/06/2020',
#   'weekNumber': 24,
#   'price': '€156,83',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '01/06/2020',
#   'endDate': '07/06/2020',
#   'weekNumber': 23,
#   'price': '€162,20',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '01/06/2020',
#   'endDate': '07/06/2020',
#   'weekNumber': 23,
#   'price': '€156,07',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '25/05/2020',
#   'endDate': '31/05/2020',
#   'weekNumber': 22,
#   'price': '€164,16',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '25/05/2020',
#   'endDate': '31/05/2020',
#   'weekNumber': 22,
#   'price': '€155,07',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '18/05/2020',
#   'endDate': '24/05/2020',
#   'weekNumber': 21,
#   'price': '€167,74',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '18/05/2020',
#   'endDate': '24/05/2020',
#   'weekNumber': 21,
#   'price': '€158,86',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '11/05/2020',
#   'endDate': '17/05/2020',
#   'weekNumber': 20,
#   'price': '€171,88',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '11/05/2020',
#   'endDate': '17/05/2020',
#   'weekNumber': 20,
#   'price': '€162,41',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '04/05/2020',
#   'endDate': '10/05/2020',
#   'weekNumber': 19,
#   'price': '€175,88',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '04/05/2020',
#   'endDate': '10/05/2020',
#   'weekNumber': 19,
#   'price': '€168,06',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '27/04/2020',
#   'endDate': '03/05/2020',
#   'weekNumber': 18,
#   'price': '€177,86',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '27/04/2020',
#   'endDate': '03/05/2020',
#   'weekNumber': 18,
#   'price': '€173,57',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '20/04/2020',
#   'endDate': '26/04/2020',
#   'weekNumber': 17,
#   'price': '€177,98',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '20/04/2020',
#   'endDate': '26/04/2020',
#   'weekNumber': 17,
#   'price': '€178,84',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '13/04/2020',
#   'endDate': '19/04/2020',
#   'weekNumber': 16,
#   'price': '€177,45',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '13/04/2020',
#   'endDate': '19/04/2020',
#   'weekNumber': 16,
#   'price': '€181,33',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '06/04/2020',
#   'endDate': '12/04/2020',
#   'weekNumber': 15,
#   'price': '€179,57',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '06/04/2020',
#   'endDate': '12/04/2020',
#   'weekNumber': 15,
#   'price': '€185,95',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '30/03/2020',
#   'endDate': '05/04/2020',
#   'weekNumber': 14,
#   'price': '€181,21',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '30/03/2020',
#   'endDate': '05/04/2020',
#   'weekNumber': 14,
#   'price': '€186,25',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '23/03/2020',
#   'endDate': '29/03/2020',
#   'weekNumber': 13,
#   'price': '€181,49',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '23/03/2020',
#   'endDate': '29/03/2020',
#   'weekNumber': 13,
#   'price': '€187,89',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '16/03/2020',
#   'endDate': '22/03/2020',
#   'weekNumber': 12,
#   'price': '€185,47',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '16/03/2020',
#   'endDate': '22/03/2020',
#   'weekNumber': 12,
#   'price': '€191,64',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '09/03/2020',
#   'endDate': '15/03/2020',
#   'weekNumber': 11,
#   'price': '€185,50',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '09/03/2020',
#   'endDate': '15/03/2020',
#   'weekNumber': 11,
#   'price': '€191,21',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '02/03/2020',
#   'endDate': '08/03/2020',
#   'weekNumber': 10,
#   'price': '€185,64',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '02/03/2020',
#   'endDate': '08/03/2020',
#   'weekNumber': 10,
#   'price': '€188,47',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '24/02/2020',
#   'endDate': '01/03/2020',
#   'weekNumber': 9,
#   'price': '€189,38',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '24/02/2020',
#   'endDate': '01/03/2020',
#   'weekNumber': 9,
#   'price': '€183,78',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '17/02/2020',
#   'endDate': '23/02/2020',
#   'weekNumber': 8,
#   'price': '€191,37',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '17/02/2020',
#   'endDate': '23/02/2020',
#   'weekNumber': 8,
#   'price': '€180,46',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '10/02/2020',
#   'endDate': '16/02/2020',
#   'weekNumber': 7,
#   'price': '€191,32',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '10/02/2020',
#   'endDate': '16/02/2020',
#   'weekNumber': 7,
#   'price': '€177,62',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '03/02/2020',
#   'endDate': '09/02/2020',
#   'weekNumber': 6,
#   'price': '€190,96',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '03/02/2020',
#   'endDate': '09/02/2020',
#   'weekNumber': 6,
#   'price': '€176,49',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '27/01/2020',
#   'endDate': '02/02/2020',
#   'weekNumber': 5,
#   'price': '€190,81',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '27/01/2020',
#   'endDate': '02/02/2020',
#   'weekNumber': 5,
#   'price': '€176,22',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '20/01/2020',
#   'endDate': '26/01/2020',
#   'weekNumber': 4,
#   'price': '€190,61',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '20/01/2020',
#   'endDate': '26/01/2020',
#   'weekNumber': 4,
#   'price': '€176,22',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '13/01/2020',
#   'endDate': '19/01/2020',
#   'weekNumber': 3,
#   'price': '€190,47',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '13/01/2020',
#   'endDate': '19/01/2020',
#   'weekNumber': 3,
#   'price': '€180,07',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '06/01/2020',
#   'endDate': '12/01/2020',
#   'weekNumber': 2,
#   'price': '€190,10',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '06/01/2020',
#   'endDate': '12/01/2020',
#   'weekNumber': 2,
#   'price': '€180,62',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '30/12/2019',
#   'endDate': '05/01/2020',
#   'weekNumber': 1,
#   'price': '€190,09',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '30/12/2019',
#   'endDate': '05/01/2020',
#   'weekNumber': 1,
#   'price': '€182,59',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '23/12/2019',
#   'endDate': '29/12/2019',
#   'weekNumber': 52,
#   'price': '€189,97',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '23/12/2019',
#   'endDate': '29/12/2019',
#   'weekNumber': 52,
#   'price': '€185,68',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '16/12/2019',
#   'endDate': '22/12/2019',
#   'weekNumber': 51,
#   'price': '€190,00',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '16/12/2019',
#   'endDate': '22/12/2019',
#   'weekNumber': 51,
#   'price': '€187,66',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '09/12/2019',
#   'endDate': '15/12/2019',
#   'weekNumber': 50,
#   'price': '€189,69',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '09/12/2019',
#   'endDate': '15/12/2019',
#   'weekNumber': 50,
#   'price': '€186,96',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '02/12/2019',
#   'endDate': '08/12/2019',
#   'weekNumber': 49,
#   'price': '€189,31',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '02/12/2019',
#   'endDate': '08/12/2019',
#   'weekNumber': 49,
#   'price': '€184,47',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '25/11/2019',
#   'endDate': '01/12/2019',
#   'weekNumber': 48,
#   'price': '€189,04',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '25/11/2019',
#   'endDate': '01/12/2019',
#   'weekNumber': 48,
#   'price': '€180,43',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '18/11/2019',
#   'endDate': '24/11/2019',
#   'weekNumber': 47,
#   'price': '€188,77',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '18/11/2019',
#   'endDate': '24/11/2019',
#   'weekNumber': 47,
#   'price': '€178,04',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '11/11/2019',
#   'endDate': '17/11/2019',
#   'weekNumber': 46,
#   'price': '€186,80',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '11/11/2019',
#   'endDate': '17/11/2019',
#   'weekNumber': 46,
#   'price': '€176,64',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '04/11/2019',
#   'endDate': '10/11/2019',
#   'weekNumber': 45,
#   'price': '€182,93',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '04/11/2019',
#   'endDate': '10/11/2019',
#   'weekNumber': 45,
#   'price': '€178,69',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '28/10/2019',
#   'endDate': '03/11/2019',
#   'weekNumber': 44,
#   'price': '€178,76',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '28/10/2019',
#   'endDate': '03/11/2019',
#   'weekNumber': 44,
#   'price': '€178,08',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '21/10/2019',
#   'endDate': '27/10/2019',
#   'weekNumber': 43,
#   'price': '€178,82',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '21/10/2019',
#   'endDate': '27/10/2019',
#   'weekNumber': 43,
#   'price': '€178,84',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '14/10/2019',
#   'endDate': '20/10/2019',
#   'weekNumber': 42,
#   'price': '€178,61',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '14/10/2019',
#   'endDate': '20/10/2019',
#   'weekNumber': 42,
#   'price': '€179,15',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '07/10/2019',
#   'endDate': '13/10/2019',
#   'weekNumber': 41,
#   'price': '€178,40',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '07/10/2019',
#   'endDate': '13/10/2019',
#   'weekNumber': 41,
#   'price': '€179,98',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '30/09/2019',
#   'endDate': '06/10/2019',
#   'weekNumber': 40,
#   'price': '€178,56',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '30/09/2019',
#   'endDate': '06/10/2019',
#   'weekNumber': 40,
#   'price': '€181,25',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '23/09/2019',
#   'endDate': '29/09/2019',
#   'weekNumber': 39,
#   'price': '€174,56',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '23/09/2019',
#   'endDate': '29/09/2019',
#   'weekNumber': 39,
#   'price': '€182,12',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '16/09/2019',
#   'endDate': '22/09/2019',
#   'weekNumber': 38,
#   'price': '€174,59',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '16/09/2019',
#   'endDate': '22/09/2019',
#   'weekNumber': 38,
#   'price': '€181,37',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '09/09/2019',
#   'endDate': '15/09/2019',
#   'weekNumber': 37,
#   'price': '€174,21',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '09/09/2019',
#   'endDate': '15/09/2019',
#   'weekNumber': 37,
#   'price': '€181,85',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '02/09/2019',
#   'endDate': '08/09/2019',
#   'weekNumber': 36,
#   'price': '€174,05',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '02/09/2019',
#   'endDate': '08/09/2019',
#   'weekNumber': 36,
#   'price': '€180,12',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '26/08/2019',
#   'endDate': '01/09/2019',
#   'weekNumber': 35,
#   'price': '€173,97',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '26/08/2019',
#   'endDate': '01/09/2019',
#   'weekNumber': 35,
#   'price': '€181,78',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '19/08/2019',
#   'endDate': '25/08/2019',
#   'weekNumber': 34,
#   'price': '€170,56',
#   'unit': '100 KG',
#   'pigClass': 'E'},
# ...
#   'beginDate': '09/10/2017',
#   'endDate': '15/10/2017',
#   'weekNumber': 41,
#   'price': '€154,00',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '09/10/2017',
#   'endDate': '15/10/2017',
#   'weekNumber': 41,
#   'price': '€147,71',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '02/10/2017',
#   'endDate': '08/10/2017',
#   'weekNumber': 40,
#   'price': '€153,65',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '02/10/2017',
#   'endDate': '08/10/2017',
#   'weekNumber': 40,
#   'price': '€153,50',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '25/09/2017',
#   'endDate': '01/10/2017',
#   'weekNumber': 39,
#   'price': '€157,57',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '25/09/2017',
#   'endDate': '01/10/2017',
#   'weekNumber': 39,
#   'price': '€160,37',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '18/09/2017',
#   'endDate': '24/09/2017',
#   'weekNumber': 38,
#   'price': '€157,97',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '18/09/2017',
#   'endDate': '24/09/2017',
#   'weekNumber': 38,
#   'price': '€166,55',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '11/09/2017',
#   'endDate': '17/09/2017',
#   'weekNumber': 37,
#   'price': '€157,41',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '11/09/2017',
#   'endDate': '17/09/2017',
#   'weekNumber': 37,
#   'price': '€172,69',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '04/09/2017',
#   'endDate': '10/09/2017',
#   'weekNumber': 36,
#   'price': '€159,53',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '04/09/2017',
#   'endDate': '10/09/2017',
#   'weekNumber': 36,
#   'price': '€173,13',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '28/08/2017',
#   'endDate': '03/09/2017',
#   'weekNumber': 35,
#   'price': '€161,49',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '28/08/2017',
#   'endDate': '03/09/2017',
#   'weekNumber': 35,
#   'price': '€175,46',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '21/08/2017',
#   'endDate': '27/08/2017',
#   'weekNumber': 34,
#   'price': '€161,88',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '21/08/2017',
#   'endDate': '27/08/2017',
#   'weekNumber': 34,
#   'price': '€176,16',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '14/08/2017',
#   'endDate': '20/08/2017',
#   'weekNumber': 33,
#   'price': '€161,65',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '14/08/2017',
#   'endDate': '20/08/2017',
#   'weekNumber': 33,
#   'price': '€176,48',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '07/08/2017',
#   'endDate': '13/08/2017',
#   'weekNumber': 32,
#   'price': '€163,53',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '07/08/2017',
#   'endDate': '13/08/2017',
#   'weekNumber': 32,
#   'price': '€173,85',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '31/07/2017',
#   'endDate': '06/08/2017',
#   'weekNumber': 31,
#   'price': '€166,84',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '31/07/2017',
#   'endDate': '06/08/2017',
#   'weekNumber': 31,
#   'price': '€175,57',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '24/07/2017',
#   'endDate': '30/07/2017',
#   'weekNumber': 30,
#   'price': '€169,56',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '24/07/2017',
#   'endDate': '30/07/2017',
#   'weekNumber': 30,
#   'price': '€176,10',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '17/07/2017',
#   'endDate': '23/07/2017',
#   'weekNumber': 29,
#   'price': '€170,09',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '17/07/2017',
#   'endDate': '23/07/2017',
#   'weekNumber': 29,
#   'price': '€176,47',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '10/07/2017',
#   'endDate': '16/07/2017',
#   'weekNumber': 28,
#   'price': '€168,83',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '10/07/2017',
#   'endDate': '16/07/2017',
#   'weekNumber': 28,
#   'price': '€176,03',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '03/07/2017',
#   'endDate': '09/07/2017',
#   'weekNumber': 27,
#   'price': '€168,50',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '03/07/2017',
#   'endDate': '09/07/2017',
#   'weekNumber': 27,
#   'price': '€172,44',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '26/06/2017',
#   'endDate': '02/07/2017',
#   'weekNumber': 26,
#   'price': '€166,68',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '26/06/2017',
#   'endDate': '02/07/2017',
#   'weekNumber': 26,
#   'price': '€170,20',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '19/06/2017',
#   'endDate': '25/06/2017',
#   'weekNumber': 25,
#   'price': '€166,39',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '19/06/2017',
#   'endDate': '25/06/2017',
#   'weekNumber': 25,
#   'price': '€172,92',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '12/06/2017',
#   'endDate': '18/06/2017',
#   'weekNumber': 24,
#   'price': '€165,99',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '12/06/2017',
#   'endDate': '18/06/2017',
#   'weekNumber': 24,
#   'price': '€170,28',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '05/06/2017',
#   'endDate': '11/06/2017',
#   'weekNumber': 23,
#   'price': '€165,33',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '05/06/2017',
#   'endDate': '11/06/2017',
#   'weekNumber': 23,
#   'price': '€170,59',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '29/05/2017',
#   'endDate': '04/06/2017',
#   'weekNumber': 22,
#   'price': '€165,50',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '29/05/2017',
#   'endDate': '04/06/2017',
#   'weekNumber': 22,
#   'price': '€167,86',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '22/05/2017',
#   'endDate': '28/05/2017',
#   'weekNumber': 21,
#   'price': '€165,52',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '22/05/2017',
#   'endDate': '28/05/2017',
#   'weekNumber': 21,
#   'price': '€167,26',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '15/05/2017',
#   'endDate': '21/05/2017',
#   'weekNumber': 20,
#   'price': '€164,42',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '15/05/2017',
#   'endDate': '21/05/2017',
#   'weekNumber': 20,
#   'price': '€166,06',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '08/05/2017',
#   'endDate': '14/05/2017',
#   'weekNumber': 19,
#   'price': '€164,71',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '08/05/2017',
#   'endDate': '14/05/2017',
#   'weekNumber': 19,
#   'price': '€165,30',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '01/05/2017',
#   'endDate': '07/05/2017',
#   'weekNumber': 18,
#   'price': '€164,80',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '01/05/2017',
#   'endDate': '07/05/2017',
#   'weekNumber': 18,
#   'price': '€166,26',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '24/04/2017',
#   'endDate': '30/04/2017',
#   'weekNumber': 17,
#   'price': '€164,52',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '24/04/2017',
#   'endDate': '30/04/2017',
#   'weekNumber': 17,
#   'price': '€164,97',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '17/04/2017',
#   'endDate': '23/04/2017',
#   'weekNumber': 16,
#   'price': '€164,43',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '17/04/2017',
#   'endDate': '23/04/2017',
#   'weekNumber': 16,
#   'price': '€166,25',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '10/04/2017',
#   'endDate': '16/04/2017',
#   'weekNumber': 15,
#   'price': '€164,71',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '10/04/2017',
#   'endDate': '16/04/2017',
#   'weekNumber': 15,
#   'price': '€166,45',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '03/04/2017',
#   'endDate': '09/04/2017',
#   'weekNumber': 14,
#   'price': '€164,25',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '03/04/2017',
#   'endDate': '09/04/2017',
#   'weekNumber': 14,
#   'price': '€160,68',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '27/03/2017',
#   'endDate': '02/04/2017',
#   'weekNumber': 13,
#   'price': '€163,72',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '27/03/2017',
#   'endDate': '02/04/2017',
#   'weekNumber': 13,
#   'price': '€156,64',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '20/03/2017',
#   'endDate': '26/03/2017',
#   'weekNumber': 12,
#   'price': '€163,71',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '20/03/2017',
#   'endDate': '26/03/2017',
#   'weekNumber': 12,
#   'price': '€154,69',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '13/03/2017',
#   'endDate': '19/03/2017',
#   'weekNumber': 11,
#   'price': '€165,58',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '13/03/2017',
#   'endDate': '19/03/2017',
#   'weekNumber': 11,
#   'price': '€153,30',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '06/03/2017',
#   'endDate': '12/03/2017',
#   'weekNumber': 10,
#   'price': '€163,55',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '06/03/2017',
#   'endDate': '12/03/2017',
#   'weekNumber': 10,
#   'price': '€149,56',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '27/02/2017',
#   'endDate': '05/03/2017',
#   'weekNumber': 9,
#   'price': '€163,19',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '27/02/2017',
#   'endDate': '05/03/2017',
#   'weekNumber': 9,
#   'price': '€147,46',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '20/02/2017',
#   'endDate': '26/02/2017',
#   'weekNumber': 8,
#   'price': '€159,79',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '20/02/2017',
#   'endDate': '26/02/2017',
#   'weekNumber': 8,
#   'price': '€146,37',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '13/02/2017',
#   'endDate': '19/02/2017',
#   'weekNumber': 7,
#   'price': '€158,82',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '13/02/2017',
#   'endDate': '19/02/2017',
#   'weekNumber': 7,
#   'price': '€144,29',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '06/02/2017',
#   'endDate': '12/02/2017',
#   'weekNumber': 6,
#   'price': '€154,96',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '06/02/2017',
#   'endDate': '12/02/2017',
#   'weekNumber': 6,
#   'price': '€141,36',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '30/01/2017',
#   'endDate': '05/02/2017',
#   'weekNumber': 5,
#   'price': '€155,06',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '30/01/2017',
#   'endDate': '05/02/2017',
#   'weekNumber': 5,
#   'price': '€142,19',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '23/01/2017',
#   'endDate': '29/01/2017',
#   'weekNumber': 4,
#   'price': '€154,48',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '23/01/2017',
#   'endDate': '29/01/2017',
#   'weekNumber': 4,
#   'price': '€140,84',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '16/01/2017',
#   'endDate': '22/01/2017',
#   'weekNumber': 3,
#   'price': '€154,17',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '16/01/2017',
#   'endDate': '22/01/2017',
#   'weekNumber': 3,
#   'price': '€140,03',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '09/01/2017',
#   'endDate': '15/01/2017',
#   'weekNumber': 2,
#   'price': '€153,10',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '09/01/2017',
#   'endDate': '15/01/2017',
#   'weekNumber': 2,
#   'price': '€139,70',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'IE',
#   'memberStateName': 'Ireland',
#   'beginDate': '02/01/2017',
#   'endDate': '08/01/2017',
#   'weekNumber': 1,
#   'price': '€153,27',
#   'unit': '100 KG',
#   'pigClass': 'E'},
#  {'memberStateCode': 'ES',
#   'memberStateName': 'Spain',
#   'beginDate': '02/01/2017',
#   'endDate': '08/01/2017',
#   'weekNumber': 1,
#   'price': '€139,08',
#   'unit': '100 KG',
#   'pigClass': 'E'}]

# %%
# save the json text file into a new variable
pig_price = json.loads(response_pigprice.text)
print(type(pig_price))
print(pig_price)
# Out:
# <class 'list'>
# [{'memberStateCode': 'IE', 'memberStateName': 'Ireland', 'beginDate': '27/12/2021', 'endDate': '02/01/2022', 'weekNumber': 52, 'price': '€143,39', 'unit': '100 KG', 'pigClass': 'E'}, {'memberStateCode': 'ES', 'memberStateName': 'Spain', 'beginDate': '27/12/2021', 'endDate': '02/01/2022', 'weekNumber': 52, 'price': '€126,29', 'unit': '100 KG', 'pigClass': 'E'}, {'memberStateCode': 'IE', 'memberStateName': 'Ireland', 'beginDate': '20/12/2021', 'endDate': '26/12/2021', 'weekNumber': 51, 'price': '€143,57', 'unit': '100 KG', 'pigClass': 'E'}, {'memberStateCode': 'ES', 'memberStateName': 'Spain', 'beginDate': '20/12/2021', 'endDate': '26/12/2021', 'weekNumber': 51, 'price': '€127,28', 'unit': '100 KG', 'pigClass': 'E'}, {'memberStateCode': 'IE', 'memberStateName': 'Ireland', 'beginDate': '13/12/2021', 'endDate': '19/12/2021', 'weekNumber': 50, 'price': '€143,77', 'unit': '100 KG', 'pigClass': 'E'}, {'memberStateCode': 'ES', 'memberStateName': 'Spain', 'beginDate': '13/12/2021', 'endDate': '19/12/2021', 'weekNumber': 50, 'price': '€126,07', 'unit': '100 KG', 'pigClass': 'E'}, {'memberStateCode': 'IE', 'memberStateName': 'Ireland', 'beginDate': '06/12/2021', 'endDate': '12/12/2021', 'weekNumber': 49, 'price': '€143,47', 'unit': '100 KG', 'pigClass': 'E'}, {'memberStateCode': 'ES', 'memberStateName': 'Spain', 'beginDate': '06/12/2021', 'endDate': '12/12/2021', 'weekNumber': 49, 'price': '€123,88', 'unit': '100 KG', 'pigClass': 'E'}, {'memberStateCode': 'IE', 'memberStateName': 'Ireland', 'beginDate': '29/11/2021', 'endDate': '05/12/2021', 'weekNumber': 48, 'price': '€143,65', 'unit': '100 KG', 'pigClass': 'E'}, {'memberStateCode': 'ES', 'memberStateName': 'Spain', 'beginDate': '29/11/2021', 'endDate': '05/12/2021', 'weekNumber': 48, 'price': '€126,01', 'unit': '100 KG', 'pigClass': 'E'}, {'memberStateCode': 'IE', 'memberStateName': 'Ireland', 'beginDate': '22/11/2021', 'endDate': '28/11/2021', 'weekNumber': 47, 'price': '€143,36', 'unit': '100 KG', 'pigClass': 'E'}, {'memberStateCode': 'ES', 'memberStateName': 'Spain', 'beginDate': '22/11/2021', 'endDate': '28/11/2021', 'weekNumber': 47, 'price': '€125,56', 'unit': '100 KG', 'pigClass': 'E'}, {'memberStateCode': 'IE', 'memberStateName': 'Ireland', 'beginDate': '15/11/2021', 'endDate': '21/11/2021', 'weekNumber': 46, 'price': '€143,22', 'unit': '100 KG', 'pigClass': 'E'}, {'memberStateCode': 'ES', 'memberStateName': 'Spain', 'beginDate': '15/11/2021', 'endDate': '21/11/2021', 'weekNumber': 46, 'price': '€126,49', 'unit': '100 KG', 'pigClass': 'E'}, {'memberStateCode': 'IE', 'memberStateName': 'Ireland', 'beginDate': '08/11/2021', 'endDate': '14/11/2021', 'weekNumber': 45, 'price': '€143,50', 'unit': '100 KG', 'pigClass': 'E'}, {'memberStateCode': 'ES', 'memberStateName': 'Spain', 'beginDate': '08/11/2021', 'endDate': '14/11/2021', 'weekNumber': 45, 'price': '€126,30', 'unit': '100 KG', 'pigClass': 'E'}, {'memberStateCode': 'IE', 'memberStateName': 'Ireland', 'beginDate': '01/11/2021', 'endDate': '07/11/2021', 'weekNumber': 44, 'price': '€143,48', 'unit': '100 KG', 'pigClass': 'E'}, {'memberStateCode': 'ES', 'memberStateName': 'Spain', 'beginDate': '01/11/2021', 'endDate': '07/11/2021', 'weekNumber': 44, 'price': '€126,49', 'unit': '100 KG', 'pigClass': 'E'}, {'memberStateCode': 'IE', 'memberStateName': 'Ireland', 'beginDate': '25/10/2021', 'endDate': '31/10/2021', 'weekNumber': 43, 'price': '€145,76', 'unit': '100 KG', 'pigClass': 'E'}, {'memberStateCode': 'ES', 'memberStateName': 'Spain', 'beginDate': '25/10/2021', 'endDate': '31/10/2021', 'weekNumber': 43, 'price': '€128,52', 'unit': '100 KG', 'pigClass': 'E'}, {'memberStateCode': 'IE', 'memberStateName': 'Ireland', 'beginDate': '18/10/2021', 'endDate': '24/10/2021', 'weekNumber': 42, 'price': '€147,75', 'unit': '100 KG', 'pigClass': 'E'}, {'memberStateCode': 'ES', 'memberStateName': 'Spain', 'beginDate': '18/10/2021', 'endDate': '24/10/2021', 'weekNumber': 42, 'price': '€130,50', 'unit': '100 KG', 'pigClass': 'E'}, {'memberStateCode ...

# %%
# write a pandas dataframe using the json text file list
df_pigprice = pd.DataFrame(pig_price)
df_pigprice.head()
# Out:
#   memberStateCode memberStateName   beginDate     endDate  weekNumber  \
# 0              IE         Ireland  27/12/2021  02/01/2022          52
# 1              ES           Spain  27/12/2021  02/01/2022          52
# 2              IE         Ireland  20/12/2021  26/12/2021          51
# 3              ES           Spain  20/12/2021  26/12/2021          51
# 4              IE         Ireland  13/12/2021  19/12/2021          50
#
#      price    unit pigClass
# 0  €143,39  100 KG        E
# 1  €126,29  100 KG        E
# 2  €143,57  100 KG        E
# 3  €127,28  100 KG        E
# 4  €143,77  100 KG        E

# %%
df_pigprice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   memberStateCode  520 non-null    object
#  1   memberStateName  520 non-null    object
#  2   beginDate        520 non-null    object
#  3   endDate          520 non-null    object
#  4   weekNumber       520 non-null    int64
#  5   price            520 non-null    object
#  6   unit             520 non-null    object
#  7   pigClass         520 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 32.6+ KB

# %%
df_pigprice.shape
# Out:
# (520, 8)

# %%
df_pigprice.isnull().sum()
# Out:
# memberStateCode    0
# memberStateName    0
# beginDate          0
# endDate            0
# weekNumber         0
# price              0
# unit               0
# pigClass           0
# dtype: int64

# %%
# create another function for convert dates
def date_conversion2(el):
    return datetime.strptime(el, "%d/%m/%Y").strftime("%Y-%m")

df_pigprice["date"] = df_pigprice["beginDate"].apply(date_conversion2)
df_pigprice.head()
# Out:
#   memberStateCode memberStateName   beginDate     endDate  weekNumber  \
# 0              IE         Ireland  27/12/2021  02/01/2022          52
# 1              ES           Spain  27/12/2021  02/01/2022          52
# 2              IE         Ireland  20/12/2021  26/12/2021          51
# 3              ES           Spain  20/12/2021  26/12/2021          51
# 4              IE         Ireland  13/12/2021  19/12/2021          50
#
#      price    unit pigClass     date
# 0  €143,39  100 KG        E  2021-12
# 1  €126,29  100 KG        E  2021-12
# 2  €143,57  100 KG        E  2021-12
# 3  €127,28  100 KG        E  2021-12
# 4  €143,77  100 KG        E  2021-12

# %%
# create a function to remove euro sign
def remove_euro(x):
    return float(x.replace("€", "").replace(",", "."))

# apply the function to remove
df_pigprice["price"] = df_pigprice["price"].apply(remove_euro)
df_pigprice
# Out:
#     memberStateCode memberStateName   beginDate     endDate  weekNumber  \
# 0                IE         Ireland  27/12/2021  02/01/2022          52
# 1                ES           Spain  27/12/2021  02/01/2022          52
# 2                IE         Ireland  20/12/2021  26/12/2021          51
# 3                ES           Spain  20/12/2021  26/12/2021          51
# 4                IE         Ireland  13/12/2021  19/12/2021          50
# ..              ...             ...         ...         ...         ...
# 515              ES           Spain  16/01/2017  22/01/2017           3
# 516              IE         Ireland  09/01/2017  15/01/2017           2
# 517              ES           Spain  09/01/2017  15/01/2017           2
# 518              IE         Ireland  02/01/2017  08/01/2017           1
# 519              ES           Spain  02/01/2017  08/01/2017           1
#
#       price    unit pigClass     date
# 0    143.39  100 KG        E  2021-12
# 1    126.29  100 KG        E  2021-12
# 2    143.57  100 KG        E  2021-12
# 3    127.28  100 KG        E  2021-12
# 4    143.77  100 KG        E  2021-12
# ..      ...     ...      ...      ...
# 515  140.03  100 KG        E  2017-01
# 516  153.10  100 KG        E  2017-01
# 517  139.70  100 KG        E  2017-01
# 518  153.27  100 KG        E  2017-01
# 519  139.08  100 KG        E  2017-01
#
# [520 rows x 9 columns]

# %%
# similarly to beef price, convert weekly price to average monthly price for merging later
df_pigprice_group = df_pigprice.groupby(["memberStateName", "date"]).transform("mean")
df_pigprice_group
# Out:
#      weekNumber    price
# 0          50.5  143.550
# 1          50.5  125.880
# 2          50.5  143.550
# 3          50.5  125.880
# 4          50.5  143.550
# ..          ...      ...
# 515         3.0  140.368
# 516         3.0  154.016
# 517         3.0  140.368
# 518         3.0  154.016
# 519         3.0  140.368
#
# [520 rows x 2 columns]

# %%
df_pigprice["pig price"] = df_pigprice_group["price"]
df_pigprice.head(10)
# Out:
#   memberStateCode memberStateName   beginDate     endDate  weekNumber   price  \
# 0              IE         Ireland  27/12/2021  02/01/2022          52  143.39
# 1              ES           Spain  27/12/2021  02/01/2022          52  126.29
# 2              IE         Ireland  20/12/2021  26/12/2021          51  143.57
# 3              ES           Spain  20/12/2021  26/12/2021          51  127.28
# 4              IE         Ireland  13/12/2021  19/12/2021          50  143.77
# 5              ES           Spain  13/12/2021  19/12/2021          50  126.07
# 6              IE         Ireland  06/12/2021  12/12/2021          49  143.47
# 7              ES           Spain  06/12/2021  12/12/2021          49  123.88
# 8              IE         Ireland  29/11/2021  05/12/2021          48  143.65
# 9              ES           Spain  29/11/2021  05/12/2021          48  126.01
#
#      unit pigClass     date  pig price
# 0  100 KG        E  2021-12    143.550
# 1  100 KG        E  2021-12    125.880
# 2  100 KG        E  2021-12    143.550
# 3  100 KG        E  2021-12    125.880
# 4  100 KG        E  2021-12    143.550
# 5  100 KG        E  2021-12    125.880
# 6  100 KG        E  2021-12    143.550
# 7  100 KG        E  2021-12    125.880
# 8  100 KG        E  2021-11    143.442
# 9  100 KG        E  2021-11    126.170

# %%
df_pigprice = df_pigprice.drop_duplicates(["memberStateName", "pig price"], keep = "last")
df_pigprice.head(20)
# Out:
#    memberStateCode memberStateName   beginDate     endDate  weekNumber  \
# 6               IE         Ireland  06/12/2021  12/12/2021          49
# 7               ES           Spain  06/12/2021  12/12/2021          49
# 16              IE         Ireland  01/11/2021  07/11/2021          44
# 17              ES           Spain  01/11/2021  07/11/2021          44
# 24              IE         Ireland  04/10/2021  10/10/2021          40
# 25              ES           Spain  04/10/2021  10/10/2021          40
# 32              IE         Ireland  06/09/2021  12/09/2021          36
# 33              ES           Spain  06/09/2021  12/09/2021          36
# 42              IE         Ireland  02/08/2021  08/08/2021          31
# 43              ES           Spain  02/08/2021  08/08/2021          31
# 50              IE         Ireland  05/07/2021  11/07/2021          27
# 51              ES           Spain  05/07/2021  11/07/2021          27
# 58              IE         Ireland  07/06/2021  13/06/2021          23
# 59              ES           Spain  07/06/2021  13/06/2021          23
# 68              IE         Ireland  03/05/2021  09/05/2021          18
# 69              ES           Spain  03/05/2021  09/05/2021          18
# 76              IE         Ireland  05/04/2021  11/04/2021          14
# 77              ES           Spain  05/04/2021  11/04/2021          14
# 86              IE         Ireland  01/03/2021  07/03/2021           9
# 87              ES           Spain  01/03/2021  07/03/2021           9
#
#      price    unit pigClass     date  pig price
# 6   143.47  100 KG        E  2021-12   143.5500
# 7   123.88  100 KG        E  2021-12   125.8800
# 16  143.48  100 KG        E  2021-11   143.4420
# 17  126.49  100 KG        E  2021-11   126.1700
# 24  149.77  100 KG        E  2021-10   147.7700
# 25  138.84  100 KG        E  2021-10   133.1775
# 32  151.40  100 KG        E  2021-09   151.5025
# 33  150.16  100 KG        E  2021-09   146.1300
# 42  159.36  100 KG        E  2021-08   155.7540
# 43  159.66  100 KG        E  2021-08   155.6220
# 50  163.30  100 KG        E  2021-07   160.7775
# 51  179.10  100 KG        E  2021-07   172.3150
# 58  167.26  100 KG        E  2021-06   167.2300
# 59  188.85  100 KG        E  2021-06   188.5200
# 68  164.82  100 KG        E  2021-05   165.7720
# 69  177.91  100 KG        E  2021-05   182.3100
# 76  159.16  100 KG        E  2021-04   162.6050
# 77  177.48  100 KG        E  2021-04   178.3350
# 86  151.37  100 KG        E  2021-03   155.2700
# 87  150.85  100 KG        E  2021-03   164.6380

# %%
df_pigprice = df_pigprice.drop(columns = {"memberStateCode", "beginDate", "endDate",
                                                       "weekNumber", "price", "unit", "pigClass"})
df_pigprice.head()
# Out:
#    memberStateName     date  pig price
# 6          Ireland  2021-12    143.550
# 7            Spain  2021-12    125.880
# 16         Ireland  2021-11    143.442
# 17           Spain  2021-11    126.170
# 24         Ireland  2021-10    147.770

# %%
df_pigprice.columns = ["country", "date", "pig price/100kg"]
new_order4 = [1, 0, 2]
df_pigprice = df_pigprice[df_pigprice.columns[new_order4]]
df_pigprice.head()
# Out:
#        date  country  pig price/100kg
# 6   2021-12  Ireland          143.550
# 7   2021-12    Spain          125.880
# 16  2021-11  Ireland          143.442
# 17  2021-11    Spain          126.170
# 24  2021-10  Ireland          147.770

# %%
df_pigprice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 120 entries, 6 to 519
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             120 non-null    object
#  1   country          120 non-null    object
#  2   pig price/100kg  120 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 3.8+ KB

# %%
df_pigprice.shape
# Out:
# (120, 3)

# %%
df_pigprice["country"].unique()
# Out:
# array(['Ireland', 'Spain'], dtype=object)

# %% [markdown]
# #### 1.3 Data merging

# %% [markdown]
# In order to do an overall analysis, the four dataset were merged accordingly into two datasets for analysis:
# - **ireland_beef** was merged to only analyse the beef price in Ireland and comparing to other factors;
# - **ie_es_beef** was merged to compare the beef price between Ireland and Spain etc., however, the feedstuff price was excluded since the feedstuff price in Spain could not be collected.

# %% [markdown]
# #### 1.3.1 Merge to ireland_beef

# %%
ireland_beef_price = beef_price.query("country == 'Ireland'")
ireland_beef_price.head()
# Out:
#        date  country     category product  beef price/100kg
# 24  2021-12  Ireland        Bulls    B R3          321.9675
# 26  2021-12  Ireland         Cows    D R3          378.2125
# 28  2021-12  Ireland      Heifers    E R3          431.5850
# 29  2021-12  Ireland       Steers    C R3          427.8350
# 30  2021-12  Ireland  Young bulls    A R3          407.8750

# %%
ireland_beef_production = beef_production.query("country == 'Ireland'")
ireland_beef_production.head()
# Out:
#       date  country category  1000 heads     kg/head
# 0  2021-01  Ireland    Bulls       15.67  376.515635
# 1  2021-02  Ireland    Bulls       14.85  383.164983
# 2  2021-03  Ireland    Bulls       14.19  394.644116
# 3  2021-04  Ireland    Bulls       11.95  403.347280
# 4  2021-05  Ireland    Bulls       15.61  393.978219

# %%
ireland_pigmeat_price = df_pigprice.query("country == 'Ireland'")
ireland_pigmeat_price.head()
# Out:
#        date  country  pig price/100kg
# 6   2021-12  Ireland         143.5500
# 16  2021-11  Ireland         143.4420
# 24  2021-10  Ireland         147.7700
# 32  2021-09  Ireland         151.5025
# 42  2021-08  Ireland         155.7540

# %%
from functools import reduce

# define the datasets that need to be merged
df_merge = [ireland_beef_price, ireland_beef_production]

# merge datasets
ireland_beef = reduce(lambda left, right: pd.merge(left, right, on = ["date", "category"]), df_merge)
ireland_beef
# Out:
#         date country_x     category product  beef price/100kg country_y  \
# 0    2021-12   Ireland        Bulls    B R3          321.9675   Ireland
# 1    2021-12   Ireland         Cows    D R3          378.2125   Ireland
# 2    2021-12   Ireland      Heifers    E R3          431.5850   Ireland
# 3    2021-12   Ireland       Steers    C R3          427.8350   Ireland
# 4    2021-12   Ireland  Young bulls    A R3          407.8750   Ireland
# ..       ...       ...          ...     ...               ...       ...
# 295  2017-01   Ireland        Bulls    B R3          300.2640   Ireland
# 296  2017-01   Ireland         Cows    D R3          321.6440   Ireland
# 297  2017-01   Ireland      Heifers    E R3          383.6880   Ireland
# 298  2017-01   Ireland       Steers    C R3          370.5560   Ireland
# 299  2017-01   Ireland  Young bulls    A R3          361.8120   Ireland
#
#      1000 heads     kg/head
# 0         15.52  371.134021
# 1         33.75  297.777778
# 2         45.77  305.003277
# 3         45.87  343.579682
# 4          0.19  210.526316
# ..          ...         ...
# 295       24.61  371.800081
# 296       27.80  317.266187
# 297       50.57  311.647222
# 298       46.02  351.803564
# 299        0.18  222.222222
#
# [300 rows x 8 columns]

# %%
df_merge2 = [ireland_beef, ireland_pigmeat_price, feedstuff1, feedstuff2]

ireland_beef = reduce(lambda left, right: pd.merge(left, right, on = ["date"]), df_merge2)
ireland_beef
# Out:
#         date country_x     category product  beef price/100kg country_y  \
# 0    2021-12   Ireland        Bulls    B R3          321.9675   Ireland
# 1    2021-12   Ireland         Cows    D R3          378.2125   Ireland
# 2    2021-12   Ireland      Heifers    E R3          431.5850   Ireland
# 3    2021-12   Ireland       Steers    C R3          427.8350   Ireland
# 4    2021-12   Ireland  Young bulls    A R3          407.8750   Ireland
# ..       ...       ...          ...     ...               ...       ...
# 295  2017-01   Ireland        Bulls    B R3          300.2640   Ireland
# 296  2017-01   Ireland         Cows    D R3          321.6440   Ireland
# 297  2017-01   Ireland      Heifers    E R3          383.6880   Ireland
# 298  2017-01   Ireland       Steers    C R3          370.5560   Ireland
# 299  2017-01   Ireland  Young bulls    A R3          361.8120   Ireland
#
#      1000 heads     kg/head  country  pig price/100kg  \
# 0         15.52  371.134021  Ireland          143.550
# 1         33.75  297.777778  Ireland          143.550
# 2         45.77  305.003277  Ireland          143.550
# 3         45.87  343.579682  Ireland          143.550
# 4          0.19  210.526316  Ireland          143.550
# ..          ...         ...      ...              ...
# 295       24.61  371.800081  Ireland          154.016
# 296       27.80  317.266187  Ireland          154.016
# 297       50.57  311.647222  Ireland          154.016
# 298       46.02  351.803564  Ireland          154.016
# 299        0.18  222.222222  Ireland          154.016
#
#                                           feedstuff_x  \
# 0    Cattle fattening nuts and cubes (13-15% protein)
# 1    Cattle fattening nuts and cubes (13-15% protein)
# 2    Cattle fattening nuts and cubes (13-15% protein)
# 3    Cattle fattening nuts and cubes (13-15% protein)
# 4    Cattle fattening nuts and cubes (13-15% protein)
# ..                                                ...
# 295  Cattle fattening nuts and cubes (13-15% protein)
# 296  Cattle fattening nuts and cubes (13-15% protein)
# 297  Cattle fattening nuts and cubes (13-15% protein)
# 298  Cattle fattening nuts and cubes (13-15% protein)
# 299  Cattle fattening nuts and cubes (13-15% protein)
#
#      beef feeding price/tonne_x                             feedstuff_y  \
# 0                        345.13  Cattle fattening meal (13-15% protein)
# 1                        345.13  Cattle fattening meal (13-15% protein)
# 2                        345.13  Cattle fattening meal (13-15% protein)
# 3                        345.13  Cattle fattening meal (13-15% protein)
# 4                        345.13  Cattle fattening meal (13-15% protein)
# ..                          ...                                     ...
# 295                      262.44  Cattle fattening meal (13-15% protein)
# 296                      262.44  Cattle fattening meal (13-15% protein)
# 297                      262.44  Cattle fattening meal (13-15% protein)
# 298                      262.44  Cattle fattening meal (13-15% protein)
# 299                      262.44  Cattle fattening meal (13-15% protein)
#
#      beef feeding price/tonne_y
# 0                        339.30
# 1                        339.30
# 2                        339.30
# 3                        339.30
# 4                        339.30
# ..                          ...
# 295                      250.44
# 296                      250.44
# 297                      250.44
# 298                      250.44
# 299                      250.44
#
# [300 rows x 14 columns]

# %%
# combine category and product columns into one column
ireland_beef["category"] = ireland_beef["category"] + " (" + ireland_beef["product"] + ")"
ireland_beef
# Out:
#         date country_x            category product  beef price/100kg  \
# 0    2021-12   Ireland        Bulls (B R3)    B R3          321.9675
# 1    2021-12   Ireland         Cows (D R3)    D R3          378.2125
# 2    2021-12   Ireland      Heifers (E R3)    E R3          431.5850
# 3    2021-12   Ireland       Steers (C R3)    C R3          427.8350
# 4    2021-12   Ireland  Young bulls (A R3)    A R3          407.8750
# ..       ...       ...                 ...     ...               ...
# 295  2017-01   Ireland        Bulls (B R3)    B R3          300.2640
# 296  2017-01   Ireland         Cows (D R3)    D R3          321.6440
# 297  2017-01   Ireland      Heifers (E R3)    E R3          383.6880
# 298  2017-01   Ireland       Steers (C R3)    C R3          370.5560
# 299  2017-01   Ireland  Young bulls (A R3)    A R3          361.8120
#
#     country_y  1000 heads     kg/head  country  pig price/100kg  \
# 0     Ireland       15.52  371.134021  Ireland          143.550
# 1     Ireland       33.75  297.777778  Ireland          143.550
# 2     Ireland       45.77  305.003277  Ireland          143.550
# 3     Ireland       45.87  343.579682  Ireland          143.550
# 4     Ireland        0.19  210.526316  Ireland          143.550
# ..        ...         ...         ...      ...              ...
# 295   Ireland       24.61  371.800081  Ireland          154.016
# 296   Ireland       27.80  317.266187  Ireland          154.016
# 297   Ireland       50.57  311.647222  Ireland          154.016
# 298   Ireland       46.02  351.803564  Ireland          154.016
# 299   Ireland        0.18  222.222222  Ireland          154.016
#
#                                           feedstuff_x  \
# 0    Cattle fattening nuts and cubes (13-15% protein)
# 1    Cattle fattening nuts and cubes (13-15% protein)
# 2    Cattle fattening nuts and cubes (13-15% protein)
# 3    Cattle fattening nuts and cubes (13-15% protein)
# 4    Cattle fattening nuts and cubes (13-15% protein)
# ..                                                ...
# 295  Cattle fattening nuts and cubes (13-15% protein)
# 296  Cattle fattening nuts and cubes (13-15% protein)
# 297  Cattle fattening nuts and cubes (13-15% protein)
# 298  Cattle fattening nuts and cubes (13-15% protein)
# 299  Cattle fattening nuts and cubes (13-15% protein)
#
#      beef feeding price/tonne_x                             feedstuff_y  \
# 0                        345.13  Cattle fattening meal (13-15% protein)
# 1                        345.13  Cattle fattening meal (13-15% protein)
# 2                        345.13  Cattle fattening meal (13-15% protein)
# 3                        345.13  Cattle fattening meal (13-15% protein)
# 4                        345.13  Cattle fattening meal (13-15% protein)
# ..                          ...                                     ...
# 295                      262.44  Cattle fattening meal (13-15% protein)
# 296                      262.44  Cattle fattening meal (13-15% protein)
# 297                      262.44  Cattle fattening meal (13-15% protein)
# 298                      262.44  Cattle fattening meal (13-15% protein)
# 299                      262.44  Cattle fattening meal (13-15% protein)
#
#      beef feeding price/tonne_y
# 0                        339.30
# 1                        339.30
# 2                        339.30
# 3                        339.30
# 4                        339.30
# ..                          ...
# 295                      250.44
# 296                      250.44
# 297                      250.44
# 298                      250.44
# 299                      250.44
#
# [300 rows x 14 columns]

# %%
# drop the duplicated and unnecessary columns
ireland_beef = ireland_beef.drop(columns = {"product", "country_y", "country"})
ireland_beef.head()
# Out:
#       date country_x            category  beef price/100kg  1000 heads  \
# 0  2021-12   Ireland        Bulls (B R3)          321.9675       15.52
# 1  2021-12   Ireland         Cows (D R3)          378.2125       33.75
# 2  2021-12   Ireland      Heifers (E R3)          431.5850       45.77
# 3  2021-12   Ireland       Steers (C R3)          427.8350       45.87
# 4  2021-12   Ireland  Young bulls (A R3)          407.8750        0.19
#
#       kg/head  pig price/100kg  \
# 0  371.134021           143.55
# 1  297.777778           143.55
# 2  305.003277           143.55
# 3  343.579682           143.55
# 4  210.526316           143.55
#
#                                         feedstuff_x  \
# 0  Cattle fattening nuts and cubes (13-15% protein)
# 1  Cattle fattening nuts and cubes (13-15% protein)
# 2  Cattle fattening nuts and cubes (13-15% protein)
# 3  Cattle fattening nuts and cubes (13-15% protein)
# 4  Cattle fattening nuts and cubes (13-15% protein)
#
#    beef feeding price/tonne_x                             feedstuff_y  \
# 0                      345.13  Cattle fattening meal (13-15% protein)
# 1                      345.13  Cattle fattening meal (13-15% protein)
# 2                      345.13  Cattle fattening meal (13-15% protein)
# 3                      345.13  Cattle fattening meal (13-15% protein)
# 4                      345.13  Cattle fattening meal (13-15% protein)
#
#    beef feeding price/tonne_y
# 0                       339.3
# 1                       339.3
# 2                       339.3
# 3                       339.3
# 4                       339.3

# %%
ireland_beef.columns = ["date", "country", "category", "beef price(€/100kg)", "1000 heads", "kg/head", 
                              "pigmeat price(€/100kg)", "feedstuff1", "cattle fattening nuts and cubes price(€/tonne)",
                              "feedstuff2", "cattle fattening meal(€/tonne)"]
ireland_beef.head()
# Out:
#       date  country            category  beef price(€/100kg)  1000 heads  \
# 0  2021-12  Ireland        Bulls (B R3)             321.9675       15.52
# 1  2021-12  Ireland         Cows (D R3)             378.2125       33.75
# 2  2021-12  Ireland      Heifers (E R3)             431.5850       45.77
# 3  2021-12  Ireland       Steers (C R3)             427.8350       45.87
# 4  2021-12  Ireland  Young bulls (A R3)             407.8750        0.19
#
#       kg/head  pigmeat price(€/100kg)  \
# 0  371.134021                  143.55
# 1  297.777778                  143.55
# 2  305.003277                  143.55
# 3  343.579682                  143.55
# 4  210.526316                  143.55
#
#                                          feedstuff1  \
# 0  Cattle fattening nuts and cubes (13-15% protein)
# 1  Cattle fattening nuts and cubes (13-15% protein)
# 2  Cattle fattening nuts and cubes (13-15% protein)
# 3  Cattle fattening nuts and cubes (13-15% protein)
# 4  Cattle fattening nuts and cubes (13-15% protein)
#
#    cattle fattening nuts and cubes price(€/tonne)  \
# 0                                          345.13
# 1                                          345.13
# 2                                          345.13
# 3                                          345.13
# 4                                          345.13
#
#                                feedstuff2  cattle fattening meal(€/tonne)
# 0  Cattle fattening meal (13-15% protein)                           339.3
# 1  Cattle fattening meal (13-15% protein)                           339.3
# 2  Cattle fattening meal (13-15% protein)                           339.3
# 3  Cattle fattening meal (13-15% protein)                           339.3
# 4  Cattle fattening meal (13-15% protein)                           339.3

# %%
# drop the two distinctive feedstuff columns
ireland_beef = ireland_beef.drop(columns = {"feedstuff1", "feedstuff2"})
ireland_beef.head(10)
# Out:
#       date  country            category  beef price(€/100kg)  1000 heads  \
# 0  2021-12  Ireland        Bulls (B R3)             321.9675       15.52
# 1  2021-12  Ireland         Cows (D R3)             378.2125       33.75
# 2  2021-12  Ireland      Heifers (E R3)             431.5850       45.77
# 3  2021-12  Ireland       Steers (C R3)             427.8350       45.87
# 4  2021-12  Ireland  Young bulls (A R3)             407.8750        0.19
# 5  2021-11  Ireland        Bulls (B R3)             312.5720       14.58
# 6  2021-11  Ireland         Cows (D R3)             366.9300       39.37
# 7  2021-11  Ireland      Heifers (E R3)             422.9340       55.18
# 8  2021-11  Ireland       Steers (C R3)             417.3040       61.99
# 9  2021-11  Ireland  Young bulls (A R3)             401.7100        0.17
#
#       kg/head  pigmeat price(€/100kg)  \
# 0  371.134021                 143.550
# 1  297.777778                 143.550
# 2  305.003277                 143.550
# 3  343.579682                 143.550
# 4  210.526316                 143.550
# 5  377.914952                 143.442
# 6  304.038608                 143.442
# 7  304.458137                 143.442
# 8  352.153573                 143.442
# 9  235.294118                 143.442
#
#    cattle fattening nuts and cubes price(€/tonne)  \
# 0                                          345.13
# 1                                          345.13
# 2                                          345.13
# 3                                          345.13
# 4                                          345.13
# 5                                          333.38
# 6                                          333.38
# 7                                          333.38
# 8                                          333.38
# 9                                          333.38
#
#    cattle fattening meal(€/tonne)
# 0                           339.3
# 1                           339.3
# 2                           339.3
# 3                           339.3
# 4                           339.3
# 5                           330.1
# 6                           330.1
# 7                           330.1
# 8                           330.1
# 9                           330.1

# %%
# Group the data by the 'category' column
beef_group = ireland_beef.groupby("category")

# Create a list to store the dataframes for each group
beef_list = []

# Iterate over the groups and create a separate dataframe for each group
for name, group in groups:
    beef_group = pd.DataFrame(group)
    beef_list.append(beef_group)

# Concatenate the dataframes into a single dataframe
ireland_beef_merged = reduce(lambda left, right: pd.merge(left, right, on = ["date"]), df_list)

ireland_beef_merged
# Out:
#        date country_x    category_x  beef price(€/100kg)_x  1000 heads_x  \
# 0   2021-12   Ireland  Bulls (B R3)               321.9675         15.52
# 1   2021-11   Ireland  Bulls (B R3)               312.5720         14.58
# 2   2021-10   Ireland  Bulls (B R3)               294.2975          9.12
# 3   2021-09   Ireland  Bulls (B R3)               297.3100          9.32
# 4   2021-08   Ireland  Bulls (B R3)               297.7820          9.23
# 5   2021-07   Ireland  Bulls (B R3)               303.5950         12.00
# 6   2021-06   Ireland  Bulls (B R3)               319.1475         15.52
# 7   2021-05   Ireland  Bulls (B R3)               325.5100         15.61
# 8   2021-04   Ireland  Bulls (B R3)               326.8400         11.95
# 9   2021-03   Ireland  Bulls (B R3)               323.6140         14.19
# 10  2021-02   Ireland  Bulls (B R3)               294.4900         14.85
# 11  2021-01   Ireland  Bulls (B R3)               284.2425         15.67
# 12  2020-12   Ireland  Bulls (B R3)               281.7125         15.62
# 13  2020-11   Ireland  Bulls (B R3)               268.0420         14.09
# 14  2020-10   Ireland  Bulls (B R3)               261.7275          9.05
# 15  2020-09   Ireland  Bulls (B R3)               258.3500          8.71
# 16  2020-08   Ireland  Bulls (B R3)               262.1960          8.50
# 17  2020-07   Ireland  Bulls (B R3)               270.0350         13.22
# 18  2020-06   Ireland  Bulls (B R3)               275.6260         16.60
# 19  2020-05   Ireland  Bulls (B R3)               296.6450         13.46
# 20  2020-04   Ireland  Bulls (B R3)               286.6225         12.95
# 21  2020-03   Ireland  Bulls (B R3)               304.8240         16.44
# 22  2020-02   Ireland  Bulls (B R3)               298.8625         20.44
# 23  2020-01   Ireland  Bulls (B R3)               271.7500         24.78
# 24  2019-12   Ireland  Bulls (B R3)               261.7720         20.52
# 25  2019-11   Ireland  Bulls (B R3)               249.4625         18.04
# 26  2019-10   Ireland  Bulls (B R3)               243.1725         14.35
# 27  2019-09   Ireland  Bulls (B R3)               261.1520          7.21
# 28  2019-08   Ireland  Bulls (B R3)               259.0850         13.00
# 29  2019-07   Ireland  Bulls (B R3)               266.5340         22.36
# 30  2019-06   Ireland  Bulls (B R3)               304.1725         23.44
# 31  2019-05   Ireland  Bulls (B R3)               320.1050         23.66
# 32  2019-04   Ireland  Bulls (B R3)               298.8600         24.08
# 33  2019-03   Ireland  Bulls (B R3)               294.5650         23.04
# 34  2019-02   Ireland  Bulls (B R3)               286.8050         26.69
# 35  2019-01   Ireland  Bulls (B R3)               282.2475         29.45
# 36  2018-12   Ireland  Bulls (B R3)               284.1160         21.38
# 37  2018-11   Ireland  Bulls (B R3)               268.8175         20.93
# 38  2018-10   Ireland  Bulls (B R3)               269.7820         16.10
# 39  2018-09   Ireland  Bulls (B R3)               271.4425         12.86
# 40  2018-08   Ireland  Bulls (B R3)               281.4975         16.26
# 41  2018-07   Ireland  Bulls (B R3)               284.6220         19.02
# 42  2018-06   Ireland  Bulls (B R3)               324.5300         23.25
# 43  2018-05   Ireland  Bulls (B R3)               343.0500         21.00
# 44  2018-04   Ireland  Bulls (B R3)               347.1860         16.39
# 45  2018-03   Ireland  Bulls (B R3)               343.0300         18.89
# 46  2018-02   Ireland  Bulls (B R3)               329.7000         23.43
# 47  2018-01   Ireland  Bulls (B R3)               311.1660         27.81
# 48  2017-12   Ireland  Bulls (B R3)               307.1475         25.06
# 49  2017-11   Ireland  Bulls (B R3)               284.3100         23.38
# 50  2017-10   Ireland  Bulls (B R3)               283.9260         14.25
# 51  2017-09   Ireland  Bulls (B R3)               274.8300         11.47
# 52  2017-08   Ireland  Bulls (B R3)               277.8100         13.62
# 53  2017-07   Ireland  Bulls (B R3)               291.2800         14.07
# 54  2017-06   Ireland  Bulls (B R3)               313.7675         21.58
# 55  2017-05   Ireland  Bulls (B R3)               333.0160         21.47
# 56  2017-04   Ireland  Bulls (B R3)               338.1575         15.32
# 57  2017-03   Ireland  Bulls (B R3)               328.5500         17.83
# 58  2017-02   Ireland  Bulls (B R3)               317.1275         22.40
# 59  2017-01   Ireland  Bulls (B R3)               300.2640         24.61
#
#      kg/head_x  pigmeat price(€/100kg)_x  \
# 0   371.134021                  143.5500
# 1   377.914952                  143.4420
# 2   391.447368                  147.7700
# 3   390.557940                  151.5025
# 4   396.533044                  155.7540
# 5   394.166667                  160.7775
# 6   384.664948                  167.2300
# 7   393.978219                  165.7720
# 8   403.347280                  162.6050
# 9   394.644116                  155.2700
# 10  383.164983                  151.5475
# 11  376.515635                  153.8825
# 12  383.482714                  156.0450
# 13  388.218595                  157.4260
# 14  403.314917                  159.2600
# 15  405.281286                  159.2400
# 16  408.235294                  161.3860
# 17  402.420575                  162.9050
# 18  387.951807                  162.3660
# 19  393.016345                  169.9150
# 20  400.000000                  178.2150
# 21  399.026764                  183.8620
# 22  388.943249                  190.7575
# 23  383.777240                  190.4975
# 24  380.604288                  189.8120
# 25  391.352550                  186.8850
# 26  397.909408                  178.6475
# 27  393.897365                  175.1940
# 28  378.461538                  171.6150
# 29  382.826476                  173.0500
# 30  380.972696                  173.0575
# 31  382.079459                  166.7925
# 32  388.704319                  152.6320
# 33  391.493056                  140.1250
# 34  378.044211                  137.3500
# 35  375.212224                  136.7275
# 36  371.375117                  138.3540
# 37  384.615385                  138.1850
# 38  367.701863                  139.9320
# 39  376.360809                  137.4550
# 40  373.923739                  137.2375
# 41  375.394322                  140.0120
# 42  375.053763                  140.6900
# 43  380.952381                  140.2675
# 44  388.651617                  139.4920
# 45  384.330334                  138.9200
# 46  375.586854                  138.4575
# 47  371.449119                  140.0920
# 48  365.921788                  145.3575
# 49  372.112917                  148.8200
# 50  374.035088                  153.6060
# 51  379.250218                  158.1200
# 52  381.057269                  162.1375
# 53  371.002132                  168.7640
# 54  373.030584                  166.0975
# 55  375.873312                  164.9900
# 56  385.770235                  164.4775
# 57  382.501402                  164.1400
# 58  376.785714                  159.1900
# 59  371.800081                  154.0160
#
#     cattle fattening nuts and cubes price(€/tonne)_x  \
# 0                                             345.13
# 1                                             333.38
# 2                                             329.13
# 3                                             324.56
# 4                                             317.75
# 5                                             317.38
# 6                                             313.44
# 7                                             310.75
# 8                                             305.38
# 9                                             301.00
# 10                                            297.44
# 11                                            294.00
# 12                                            289.63
# 13                                            285.63
# 14                                            282.82
# 15                                            281.76
# 16                                            283.24
# 17                                            282.35
# 18                                            282.35
# 19                                            281.59
# 20                                            280.12
# 21                                            276.59
# 22                                            275.71
# 23                                            276.18
# 24                                            276.47
# 25                                            277.06
# 26                                            277.24
# 27                                            281.18
# 28                                            284.41
# 29                                            286.67
# 30                                            287.72
# 31                                            289.50
# 32                                            293.79
# 33                                            293.16
# 34                                            293.37
# 35                                            293.58
# 36                                            293.05
# 37                                            293.05
# 38                                            292.47
# 39                                            290.79
# 40                                            284.53
# 41                                            279.90
# 42                                            277.95
# 43                                            275.68
# 44                                            267.84
# 45                                            266.05
# 46                                            265.79
# 47                                            262.79
# 48                                            264.68
# 49                                            264.42
# 50                                            264.32
# 51                                            265.39
# 52                                            265.67
# 53                                            265.39
# 54                                            265.39
# 55                                            265.67
# 56                                            265.39
# 57                                            265.00
# 58                                            264.56
# 59                                            262.44
#
#     cattle fattening meal(€/tonne)_x country_y  ...  \
# 0                             339.30   Ireland  ...
# 1                             330.10   Ireland  ...
# 2                             325.73   Ireland  ...
# 3                             320.40   Ireland  ...
# 4                             310.73   Ireland  ...
# 5                             310.47   Ireland  ...
# 6                             308.13   Ireland  ...
# 7                             304.73   Ireland  ...
# 8                             299.20   Ireland  ...
# 9                             294.87   Ireland  ...
# 10                            293.40   Ireland  ...
# 11                            288.73   Ireland  ...
# 12                            284.40   Ireland  ...
# 13                            279.47   Ireland  ...
# 14                            276.25   Ireland  ...
# 15                            275.00   Ireland  ...
# 16                            275.88   Ireland  ...
# 17                            275.59   Ireland  ...
# 18                            276.00   Ireland  ...
# 19                            275.29   Ireland  ...
# 20                            275.06   Ireland  ...
# 21                            271.12   Ireland  ...
# 22                            269.65   Ireland  ...
# 23                            269.65   Ireland  ...
# 24                            270.39   Ireland  ...
# 25                            270.17   Ireland  ...
# 26                            271.83   Ireland  ...
# 27                            276.06   Ireland  ...
# 28                            282.11   Ireland  ...
# 29                            282.56   Ireland  ...
# 30                            283.89   Ireland  ...
# 31                            285.36   Ireland  ...
# 32                            288.50   Ireland  ...
# 33                            287.26   Ireland  ...
# 34                            287.42   Ireland  ...
# 35                            288.24   Ireland  ...
# 36                            287.68   Ireland  ...
# 37                            287.68   Ireland  ...
# 38                            286.76   Ireland  ...
# 39                            285.29   Ireland  ...
# 40                            280.97   Ireland  ...
# 41                            274.28   Ireland  ...
# 42                            271.15   Ireland  ...
# 43                            271.21   Ireland  ...
# 44                            264.89   Ireland  ...
# 45                            262.06   Ireland  ...
# 46                            262.33   Ireland  ...
# 47                            259.11   Ireland  ...
# 48                            255.35   Ireland  ...
# 49                            255.35   Ireland  ...
# 50                            254.76   Ireland  ...
# 51                            254.47   Ireland  ...
# 52                            254.76   Ireland  ...
# 53                            250.06   Ireland  ...
# 54                            250.06   Ireland  ...
# 55                            249.75   Ireland  ...
# 56                            249.44   Ireland  ...
# 57                            249.00   Ireland  ...
# 58                            248.93   Ireland  ...
# 59                            250.44   Ireland  ...
#
#    cattle fattening nuts and cubes price(€/tonne)_y  \
# 0                                            345.13
# 1                                            333.38
# 2                                            329.13
# 3                                            324.56
# 4                                            317.75
# 5                                            317.38
# 6                                            313.44
# 7                                            310.75
# 8                                            305.38
# 9                                            301.00
# 10                                           297.44
# 11                                           294.00
# 12                                           289.63
# 13                                           285.63
# 14                                           282.82
# 15                                           281.76
# 16                                           283.24
# 17                                           282.35
# 18                                           282.35
# 19                                           281.59
# 20                                           280.12
# 21                                           276.59
# 22                                           275.71
# 23                                           276.18
# 24                                           276.47
# 25                                           277.06
# 26                                           277.24
# 27                                           281.18
# 28                                           284.41
# 29                                           286.67
# 30                                           287.72
# 31                                           289.50
# 32                                           293.79
# 33                                           293.16
# 34                                           293.37
# 35                                           293.58
# 36                                           293.05
# 37                                           293.05
# 38                                           292.47
# 39                                           290.79
# 40                                           284.53
# 41                                           279.90
# 42                                           277.95
# 43                                           275.68
# 44                                           267.84
# 45                                           266.05
# 46                                           265.79
# 47                                           262.79
# 48                                           264.68
# 49                                           264.42
# 50                                           264.32
# 51                                           265.39
# 52                                           265.67
# 53                                           265.39
# 54                                           265.39
# 55                                           265.67
# 56                                           265.39
# 57                                           265.00
# 58                                           264.56
# 59                                           262.44
#
#     cattle fattening meal(€/tonne)_y  country            category  \
# 0                             339.30  Ireland  Young bulls (A R3)
# 1                             330.10  Ireland  Young bulls (A R3)
# 2                             325.73  Ireland  Young bulls (A R3)
# 3                             320.40  Ireland  Young bulls (A R3)
# 4                             310.73  Ireland  Young bulls (A R3)
# 5                             310.47  Ireland  Young bulls (A R3)
# 6                             308.13  Ireland  Young bulls (A R3)
# 7                             304.73  Ireland  Young bulls (A R3)
# 8                             299.20  Ireland  Young bulls (A R3)
# 9                             294.87  Ireland  Young bulls (A R3)
# 10                            293.40  Ireland  Young bulls (A R3)
# 11                            288.73  Ireland  Young bulls (A R3)
# 12                            284.40  Ireland  Young bulls (A R3)
# 13                            279.47  Ireland  Young bulls (A R3)
# 14                            276.25  Ireland  Young bulls (A R3)
# 15                            275.00  Ireland  Young bulls (A R3)
# 16                            275.88  Ireland  Young bulls (A R3)
# 17                            275.59  Ireland  Young bulls (A R3)
# 18                            276.00  Ireland  Young bulls (A R3)
# 19                            275.29  Ireland  Young bulls (A R3)
# 20                            275.06  Ireland  Young bulls (A R3)
# 21                            271.12  Ireland  Young bulls (A R3)
# 22                            269.65  Ireland  Young bulls (A R3)
# 23                            269.65  Ireland  Young bulls (A R3)
# 24                            270.39  Ireland  Young bulls (A R3)
# 25                            270.17  Ireland  Young bulls (A R3)
# 26                            271.83  Ireland  Young bulls (A R3)
# 27                            276.06  Ireland  Young bulls (A R3)
# 28                            282.11  Ireland  Young bulls (A R3)
# 29                            282.56  Ireland  Young bulls (A R3)
# 30                            283.89  Ireland  Young bulls (A R3)
# 31                            285.36  Ireland  Young bulls (A R3)
# 32                            288.50  Ireland  Young bulls (A R3)
# 33                            287.26  Ireland  Young bulls (A R3)
# 34                            287.42  Ireland  Young bulls (A R3)
# 35                            288.24  Ireland  Young bulls (A R3)
# 36                            287.68  Ireland  Young bulls (A R3)
# 37                            287.68  Ireland  Young bulls (A R3)
# 38                            286.76  Ireland  Young bulls (A R3)
# 39                            285.29  Ireland  Young bulls (A R3)
# 40                            280.97  Ireland  Young bulls (A R3)
# 41                            274.28  Ireland  Young bulls (A R3)
# 42                            271.15  Ireland  Young bulls (A R3)
# 43                            271.21  Ireland  Young bulls (A R3)
# 44                            264.89  Ireland  Young bulls (A R3)
# 45                            262.06  Ireland  Young bulls (A R3)
# 46                            262.33  Ireland  Young bulls (A R3)
# 47                            259.11  Ireland  Young bulls (A R3)
# 48                            255.35  Ireland  Young bulls (A R3)
# 49                            255.35  Ireland  Young bulls (A R3)
# 50                            254.76  Ireland  Young bulls (A R3)
# 51                            254.47  Ireland  Young bulls (A R3)
# 52                            254.76  Ireland  Young bulls (A R3)
# 53                            250.06  Ireland  Young bulls (A R3)
# 54                            250.06  Ireland  Young bulls (A R3)
# 55                            249.75  Ireland  Young bulls (A R3)
# 56                            249.44  Ireland  Young bulls (A R3)
# 57                            249.00  Ireland  Young bulls (A R3)
# 58                            248.93  Ireland  Young bulls (A R3)
# 59                            250.44  Ireland  Young bulls (A R3)
#
#     beef price(€/100kg)  1000 heads     kg/head pigmeat price(€/100kg)  \
# 0              407.8750        0.19  210.526316               143.5500
# 1              401.7100        0.17  235.294118               143.4420
# 2              400.1550        0.16  187.500000               147.7700
# 3              401.0025        0.06  166.666667               151.5025
# 4              402.5800        0.07  142.857143               155.7540
# 5              413.5900        0.10  200.000000               160.7775
# 6              407.1125        0.13  230.769231               167.2300
# 7              397.1100        0.41  121.951220               165.7720
# 8              383.5850        0.74  121.621622               162.6050
# 9              363.9740        3.68  100.543478               155.2700
# 10             357.5850        1.27  110.236220               151.5475
# 11             360.6225        0.20  150.000000               153.8825
# 12             356.4025        0.23  217.391304               156.0450
# 13             348.2000        0.17  176.470588               157.4260
# 14             346.0400        0.18  166.666667               159.2600
# 15             346.6875        0.09  222.222222               159.2400
# 16             351.8920        0.11  181.818182               161.3860
# 17             358.4075        0.11  181.818182               162.9050
# 18             350.1320        0.15  200.000000               162.3660
# 19             343.5500        0.17  176.470588               169.9150
# 20             324.7625        0.09  222.222222               178.2150
# 21             341.0980        0.19  210.526316               183.8620
# 22             343.7100        0.18  222.222222               190.7575
# 23             336.4300        0.17  176.470588               190.4975
# 24             325.9720        0.24  208.333333               189.8120
# 25             320.6375        0.20  200.000000               186.8850
# 26             322.2650        0.13  230.769231               178.6475
# 27             327.5920        0.09  222.222222               175.1940
# 28             332.5650        0.11  181.818182               171.6150
# 29             342.5880        0.13  153.846154               173.0500
# 30             366.5075        0.16  187.500000               173.0575
# 31             369.8225        0.72  125.000000               166.7925
# 32             341.8320        2.02  113.861386               152.6320
# 33             339.0925        9.09  105.610561               140.1250
# 34             341.6725        7.54  106.100796               137.3500
# 35             350.3025        0.17  235.294118               136.7275
# 36             357.5040        0.15  200.000000               138.3540
# 37             363.3825        0.16  187.500000               138.1850
# 38             364.3760        0.13  230.769231               139.9320
# 39             367.9775        0.07  142.857143               137.4550
# 40             377.1475        0.11  181.818182               137.2375
# 41             384.6880        0.08  250.000000               140.0120
# 42             404.6775        0.11  181.818182               140.6900
# 43             403.5200        0.35  142.857143               140.2675
# 44             391.0800        0.96  125.000000               139.4920
# 45             381.3900        4.01  114.713217               138.9200
# 46             375.2650        4.48  113.839286               138.4575
# 47             382.8640        0.18  222.222222               140.0920
# 48             383.4975        0.12  166.666667               145.3575
# 49             372.0125        0.13  230.769231               148.8200
# 50             366.6140        0.13  230.769231               153.6060
# 51             370.2475        0.12  250.000000               158.1200
# 52             376.8450        0.06  166.666667               162.1375
# 53             392.0280        0.08  250.000000               168.7640
# 54             399.4600        0.15  200.000000               166.0975
# 55             396.3600        0.18  166.666667               164.9900
# 56             382.4125        0.74  148.648649               164.4775
# 57             368.4600        3.06  140.522876               164.1400
# 58             361.9150        2.60  142.307692               159.1900
# 59             361.8120        0.18  222.222222               154.0160
#
#    cattle fattening nuts and cubes price(€/tonne)  \
# 0                                          345.13
# 1                                          333.38
# 2                                          329.13
# 3                                          324.56
# 4                                          317.75
# 5                                          317.38
# 6                                          313.44
# 7                                          310.75
# 8                                          305.38
# 9                                          301.00
# 10                                         297.44
# 11                                         294.00
# 12                                         289.63
# 13                                         285.63
# 14                                         282.82
# 15                                         281.76
# 16                                         283.24
# 17                                         282.35
# 18                                         282.35
# 19                                         281.59
# 20                                         280.12
# 21                                         276.59
# 22                                         275.71
# 23                                         276.18
# 24                                         276.47
# 25                                         277.06
# 26                                         277.24
# 27                                         281.18
# 28                                         284.41
# 29                                         286.67
# 30                                         287.72
# 31                                         289.50
# 32                                         293.79
# 33                                         293.16
# 34                                         293.37
# 35                                         293.58
# 36                                         293.05
# 37                                         293.05
# 38                                         292.47
# 39                                         290.79
# 40                                         284.53
# 41                                         279.90
# 42                                         277.95
# 43                                         275.68
# 44                                         267.84
# 45                                         266.05
# 46                                         265.79
# 47                                         262.79
# 48                                         264.68
# 49                                         264.42
# 50                                         264.32
# 51                                         265.39
# 52                                         265.67
# 53                                         265.39
# 54                                         265.39
# 55                                         265.67
# 56                                         265.39
# 57                                         265.00
# 58                                         264.56
# 59                                         262.44
#
#     cattle fattening meal(€/tonne)
# 0                           339.30
# 1                           330.10
# 2                           325.73
# 3                           320.40
# 4                           310.73
# 5                           310.47
# 6                           308.13
# 7                           304.73
# 8                           299.20
# 9                           294.87
# 10                          293.40
# 11                          288.73
# 12                          284.40
# 13                          279.47
# 14                          276.25
# 15                          275.00
# 16                          275.88
# 17                          275.59
# 18                          276.00
# 19                          275.29
# 20                          275.06
# 21                          271.12
# 22                          269.65
# 23                          269.65
# 24                          270.39
# 25                          270.17
# 26                          271.83
# 27                          276.06
# 28                          282.11
# 29                          282.56
# 30                          283.89
# 31                          285.36
# 32                          288.50
# 33                          287.26
# 34                          287.42
# 35                          288.24
# 36                          287.68
# 37                          287.68
# 38                          286.76
# 39                          285.29
# 40                          280.97
# 41                          274.28
# 42                          271.15
# 43                          271.21
# 44                          264.89
# 45                          262.06
# 46                          262.33
# 47                          259.11
# 48                          255.35
# 49                          255.35
# 50                          254.76
# 51                          254.47
# 52                          254.76
# 53                          250.06
# 54                          250.06
# 55                          249.75
# 56                          249.44
# 57                          249.00
# 58                          248.93
# 59                          250.44
#
# [60 rows x 41 columns]

# %%
ireland_beef_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60 entries, 0 to 59
# Data columns (total 41 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   date                                              60 non-null     object
#  1   country_x                                         60 non-null     object
#  2   category_x                                        60 non-null     object
#  3   beef price(€/100kg)_x                             60 non-null     float64
#  4   1000 heads_x                                      60 non-null     float64
#  5   kg/head_x                                         60 non-null     float64
#  6   pigmeat price(€/100kg)_x                          60 non-null     float64
#  7   cattle fattening nuts and cubes price(€/tonne)_x  60 non-null     float64
#  8   cattle fattening meal(€/tonne)_x                  60 non-null     float64
#  9   country_y                                         60 non-null     object
#  10  category_y                                        60 non-null     object
#  11  beef price(€/100kg)_y                             60 non-null     float64
#  12  1000 heads_y                                      60 non-null     float64
#  13  kg/head_y                                         60 non-null     float64
#  14  pigmeat price(€/100kg)_y                          60 non-null     float64
#  15  cattle fattening nuts and cubes price(€/tonne)_y  60 non-null     float64
#  16  cattle fattening meal(€/tonne)_y                  60 non-null     float64
#  17  country_x                                         60 non-null     object
#  18  category_x                                        60 non-null     object
#  19  beef price(€/100kg)_x                             60 non-null     float64
#  20  1000 heads_x                                      60 non-null     float64
#  21  kg/head_x                                         60 non-null     float64
#  22  pigmeat price(€/100kg)_x                          60 non-null     float64
#  23  cattle fattening nuts and cubes price(€/tonne)_x  60 non-null     float64
#  24  cattle fattening meal(€/tonne)_x                  60 non-null     float64
#  25  country_y                                         60 non-null     object
#  26  category_y                                        60 non-null     object
#  27  beef price(€/100kg)_y                             60 non-null     float64
#  28  1000 heads_y                                      60 non-null     float64
#  29  kg/head_y                                         60 non-null     float64
#  30  pigmeat price(€/100kg)_y                          60 non-null     float64
#  31  cattle fattening nuts and cubes price(€/tonne)_y  60 non-null     float64
#  32  cattle fattening meal(€/tonne)_y                  60 non-null     float64
#  33  country                                           60 non-null     object
#  34  category                                          60 non-null     object
#  35  beef price(€/100kg)                               60 non-null     float64
#  36  1000 heads                                        60 non-null     float64
#  37  kg/head                                           60 non-null     float64
#  38  pigmeat price(€/100kg)                            60 non-null     float64
#  39  cattle fattening nuts and cubes price(€/tonne)    60 non-null     float64
#  40  cattle fattening meal(€/tonne)                    60 non-null     float64
# dtypes: float64(30), object(11)
# memory usage: 19.7+ KB

# %%
# Create a wide-form dataframe with separate columns for each category
df_wide = ireland_beef.pivot_table(index=["date", "country"], 
                                   columns="category", 
                                   values=["beef price(€/100kg)", "1000 heads", "kg/head"])

# Extract a dataframe for a particular category
df_category = df_wide.xs("Bulls (B R3)", level="category", axis=1)

df_wide
df_category.head()
# Out:
#                  1000 heads  beef price(€/100kg)     kg/head
# date    country
# 2017-01 Ireland       24.61             300.2640  371.800081
# 2017-02 Ireland       22.40             317.1275  376.785714
# 2017-03 Ireland       17.83             328.5500  382.501402
# 2017-04 Ireland       15.32             338.1575  385.770235
# 2017-05 Ireland       21.47             333.0160  375.873312

# %%
df_merge3 = [beef_price_analysis, feedstuff1, feedstuff2]

beef_price_analysis = reduce(lambda left, right: pd.merge(left, right, on = ["date"]), df_merge3)
beef_price_analysis
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [68], line 1
# ----> 1 df_merge3 = [beef_price_analysis, feedstuff1, feedstuff2]
#       3 beef_price_analysis = reduce(lambda left, right: pd.merge(left, right, on = ["date"]), df_merge3)
#       4 beef_price_analysis
#
# NameError: name 'beef_price_analysis' is not defined

# %%
beef_price_analysis = beef_price_analysis.sort_values(by = ["date"], ascending = True)
beef_price_analysis.head(15)

# %% [markdown]
# - **From here, the final dataset is almost ready. There are just few more modifications to do as follow.**

# %%
# combine category and product columns into one column
beef_price_analysis["category"] = beef_price_analysis["category"] + " (" + beef_price_analysis["product"] + ")"
beef_price_analysis

# %%
# drop the duplicated and unnecessary columns
beef_price_analysis = beef_price_analysis.drop(columns = {"product", "country_y", "country"})
beef_price_analysis.head()

# %%
# rename the columns
beef_price_analysis.columns = ["date", "country", "category", "beef price(€/100kg)", "1000 heads", "kg/head", 
                              "pigmeat price(€/100kg)", "feedstuff1", "cattle fattening nuts and cubes price(€/tonne)",
                              "feedstuff2", "cattle fattening meal(€/tonne)"]
beef_price_analysis.head()

# %%
# drop the two distinctive feedstuff columns
beef_price_analysis = beef_price_analysis.drop(columns = {"feedstuff1", "feedstuff2"})
beef_price_analysis.head()

# %%
# lastly, replace the two feedstuff price in Spain with value 0 since we couldn't get data for it
# columns_to_update = ["cattle fattening nuts and cubes price(€/tonne)", "cattle fattening meal(€/tonne)"]

# beef_price_analysis.loc[beef_price_analysis["country"] == "Spain", columns_to_update] = 0
# beef_price_analysis.head()

# %%
beef_price_analysis.shape

# %%
beef_price_analysis.info()

# %%
beef_price_analysis["date"] = pd.to_datetime(beef_price_analysis["date"])
beef_price_analysis.info()

# %% [markdown]
# ### 2. EDA

# %% [markdown]
# - Looking into Ireland only.

# %%
ireland = beef_price_analysis.query("country == 'Ireland'")
ireland.head()

# %%
from dataprep.eda import plot
plot(ireland)

# %%
plot(ireland, "beef price(€/100kg)", "pigmeat price(€/100kg)")

# %%
from dataprep.eda import plot_correlation
plot_correlation(ireland)

# %%
corrmat = ireland.corr()
f, ax = plt.subplots(figsize = (8, 8))
fig1 = sns.heatmap(corrmat, vmax = 1, cmap = "Paired", square = True, annot = True);

# %%
# import bokeh
# from bokeh.plotting import figure, show
# # create a new plot with a title and axis labels
# p = figure(title = "Beef Price in Ireland from 2017 to 2021", x_axis_label = "Date", 
#            y_axis_label = "Beef price(€/100kg)", sizing_mode="stretch_width", height = 400)

# # add a line renderer with legend and line thickness
# p.line(x = ireland["date"], y = ireland["beef price(€/100kg)"], legend_label = "beef price", line_width = 2)

# # show the results
# show(p)

# %%
import plotly.express as px

fig = px.line(ireland["category"], x = "date", y = "beef price(€/100kg)")
fig.show()

# %% [markdown]
# ###  Sentimental analysis

# %%
from dotenv import dotenv_values

config = dotenv_values(".env")

# %% [markdown]
# ## References

# %% [markdown]
# - <p> https://stackoverflow.com/questions/50663700/convert-year-and-month-name-into-datetime-column-for-pandas-dataframe <p>
# - <p> https://stackoverflow.com/questions/50511640/how-to-convert-string-to-datetime-without-days-in-pandas <p>
# - <p> https://stackoverflow.com/questions/56723193/convert-stringdec-2018-to-datetime <p>
